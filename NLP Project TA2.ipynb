# %%
# Required installations:
# !pip install pillow pytesseract nltk langdetect
# !sudo apt-get install tesseract-ocr
# !sudo apt-get install tesseract-ocr-hin
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.11/dist-packages (0.3.13)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Collecting langdetect
#   Using cached langdetect-1.0.9.tar.gz (981 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (24.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from langdetect) (1.17.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=33ea4656b5b0dab03f7097b0b8b5ac7d38450d0e67b9acca98f8152e4bb8bbee
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tesseract-ocr-hin
# 0 upgraded, 1 newly installed, 0 to remove and 30 not upgraded.
# Need to get 913 kB of archives.
# After this operation, 1,138 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-hin all 1:4.00~git30-7274cfa-1.1 [913 kB]
# Fetched 913 kB in 1s (1,143 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-hin.
# (Reading database ... 126315 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-hin_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-hin (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-hin (1:4.00~git30-7274cfa-1.1) ...

# %%
# Basic Extration and Tokenisation
import pytesseract
from PIL import Image
import cv2
import numpy as np
import nltk
from langdetect import detect

nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize

# 1. Load and preprocess image
def preprocess_image(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    denoised = cv2.fastNlMeansDenoising(gray, h=30)
    return denoised

# 2. Perform OCR
def extract_text(img):
    pil_img = Image.fromarray(img)
    text = pytesseract.image_to_string(pil_img, lang='hin')
    return text

# 3. Normalize text
def normalize_text(text):
    return text.replace('\n', ' ').strip()

# 4. Tokenize text
def tokenize_text(text):
    return word_tokenize(text)

# 5. NLP Task: Detect language
def detect_language(text):
    try:
        lang = detect(text)
        return lang
    except:
        return "Unknown"

# Main pipeline
if __name__ == '__main__':
    image_path = '/content/input/page3.jpg'
    img = preprocess_image(image_path)
    raw_text = extract_text(img)
    norm_text = normalize_text(raw_text)
    tokens = tokenize_text(norm_text)
    lang = detect_language(norm_text)

    print("--- Extracted Text ---")
    print(norm_text)
    print("\n--- Tokens ---")
    print(tokens)
    print("\n--- Detected Language ---")
    print(lang)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# --- Extracted Text ---
# ज्ाईंदुन्गिय्या  0वीं की परीक्षा के लिए विद्यार्थी कर सकेंगे तीन भाषा विषय का चयन  खण्डबा। माध्यमिक शिक्षा पंडल द्वारा शिक्षण सत्र 2022 23 की हाई सकल परीक्षा के लिए विद्यार्थी को निर्धारित भाषा विषयों में से कोई तोन विषय का चयन करना होगा नेशनल स्किल क्लालीफिकशन फंमवर्क विषय का चयन करने वाले विद्यार्थियों को निर्धारित भाषा विषयों में से कोई दो भाषा विषय का चयन करना होगा। चिल्डुन विथ स्पेशल नीड के विद्यार्थी गणित अथवा विज्ञान के स्थान पर चित्रकला अथवा गायन वादन अथवा तबला पखावज अथवा कम्प्यूटर विषय में से कोई एक विषय ले सकेंगे। साथ ही ऐसे परीक्षार्थियों को तौन भाषा विषय में से दो भाषा विषय में छूट प्रदान की गई है। ऐसे परीक्षार्थी किसी एक भाषा विषय का चयन कर सकेंगे। इस संबंध में निर्देश जारी कर दिए गए हैं। माध्यमिक शिक्षा मंडल द्वारा मान्यता प्राप्त संस्थाओं में सनियमित प्रवेश के लिए प्रवेश संबंधी प्ा्गंदर्शिका पुस्तिका भी जारी की गई है विधिक साक्षरता एवं जागरूकता चिविर संपन्न  छत्रपुर। छतरपुर शहर के नौंगांव रोड स्थित एक निजि संस्थान पें जिला विधिक साक्षरता एवं जागरूकता शिविर प्रधान जिला न्यायाधीश हरदेश श्रीवास्तव को उपस्थिति पें बुधवार को संपन्न हुआ। इस अवसर पर उन्होंने कहा कि भारतीय संविधान में मूल अधिकार एवं कतंव्य बताये गये है। नागरिक देश के प्रति मौलिक कतंव्य का पालन करें संविधान में समानता
दिल रखते हुए सबको साथ में लेकर आगे  भाटिया,  जयना प्रमोद सोनी, वार्ड 3 से कांग्रेस की लीला बसंत सैनी, वार्ड 4 से भाजपा की ाजकामारी 'घूनम मेषकर, बार्ड 5 से कांग्रेस  7 से भाजपा के अभय वर्मा, वार्ड 8 से भाजपा की रिचा जितू तिवारी, वार्ड 9 से भाजपा की आरती लक्ष्मण बैस, वार्ड 70  वार्ड 72 से भाजपा की पूजा मालवीय, वार्ड 3 से भाजपा की वर्षा भंडारी, वार्ड १4 से भाजपा की प्रेमा पंकज पांडे वार्ड १ से भाजपा की निर्मला हंसराय,  मतदाताओं के प्रति आभार व्यक्त किया बैठक में चंद्रपालसिंह तोमर,लादूराम साहू, सुरेंद्र पंडयाजितेंद्र सुराणा, महेंद्रसिह  निखिलेश खंडेलवाल,नरहरि दांगी, बजेंद्र जोशी,मिद्ू भाटिया,रोमेश  खहतउजड ...
#
# --- Tokens ---
# ['ज्ाईंदुन्गिय्या', '0वीं', 'की', 'परीक्षा', 'के', 'लिए', 'विद्यार्थी', 'कर', 'सकेंगे', 'तीन', 'भाषा', 'विषय', 'का', 'चयन', 'खण्डबा।', 'माध्यमिक', 'शिक्षा', 'पंडल', 'द्वारा', 'शिक्षण', 'सत्र', '2022', '23', 'की', 'हाई', 'सकल', 'परीक्षा', 'के', 'लिए', 'विद्यार्थी', 'को', 'निर्धारित', 'भाषा', 'विषयों', 'में', 'से', 'कोई', 'तोन', 'विषय', 'का', 'चयन', 'करना', 'होगा', 'नेशनल', 'स्किल', 'क्लालीफिकशन', 'फंमवर्क', 'विषय', 'का', 'चयन', 'करने', 'वाले', 'विद्यार्थियों', 'को', 'निर्धारित', 'भाषा', 'विषयों', 'में', 'से', 'कोई', 'दो', 'भाषा', 'विषय', 'का', 'चयन', 'करना', 'होगा।', 'चिल्डुन', 'विथ', 'स्पेशल', 'नीड', 'के', 'विद्यार्थी', 'गणित', 'अथवा', 'विज्ञान', 'के', 'स्थान', 'पर', 'चित्रकला', 'अथवा', 'गायन', 'वादन', 'अथवा', 'तबला', 'पखावज', 'अथवा', 'कम्प्यूटर', 'विषय', 'में', 'से', 'कोई', 'एक', 'विषय', 'ले', 'सकेंगे।', 'साथ', 'ही', 'ऐसे', 'परीक्षार्थियों', 'को', 'तौन', 'भाषा', 'विषय', 'में', 'से', 'दो', 'भाषा', 'विषय', 'में', 'छूट', 'प्रदान', 'की', 'गई', 'है।', 'ऐसे', 'परीक्षार्थी', 'किसी', 'एक', 'भाषा', 'विषय', 'का', 'चयन', 'कर', 'सकेंगे।', 'इस', 'संबंध', 'में', 'निर्देश', 'जारी', 'कर', 'दिए', 'गए', 'हैं।', 'माध्यमिक', 'शिक्षा', 'मंडल', 'द्वारा', 'मान्यता', 'प्राप्त', 'संस्थाओं', 'में', 'सनियमित', 'प्रवेश', 'के', 'लिए', 'प्रवेश', 'संबंधी', 'प्ा्गंदर्शिका', 'पुस्तिका', 'भी', 'जारी', 'की', 'गई', 'है', 'विधिक', 'साक्षरता', 'एवं', 'जागरूकता', 'चिविर', 'संपन्न', 'छत्रपुर।', 'छतरपुर', 'शहर', 'के', 'नौंगांव', 'रोड', 'स्थित', 'एक', 'निजि', 'संस्थान', 'पें', 'जिला', 'विधिक', 'साक्षरता', 'एवं', 'जागरूकता', 'शिविर', 'प्रधान', 'जिला', 'न्यायाधीश', 'हरदेश', 'श्रीवास्तव', 'को', 'उपस्थिति', 'पें', 'बुधवार', 'को', 'संपन्न', 'हुआ।', 'इस', 'अवसर', 'पर', 'उन्होंने', 'कहा', 'कि', 'भारतीय', 'संविधान', 'में', 'मूल', 'अधिकार', 'एवं', 'कतंव्य', 'बताये', 'गये', 'है।', 'नागरिक', 'देश', 'के', 'प्रति', 'मौलिक', 'कतंव्य', 'का', 'पालन', 'करें', 'संविधान', 'में', 'समानता', 'का', 'अधिकार', 'स्वतत्रता', 'का', 'अधिकार', 'तथा', 'अधिव्यक्ति', 'कौ', 'स्वतंत्रता', 'शोषण', 'के', 'विरुद्ध', 'अधिकार', 'धर्म', 'संस्कृति', 'एवं', 'शिक्षा', 'का', 'अधिकार', 'दिया', 'गया', 'है', 'नागरिकों', 'कतंव्य', 'में', 'संविधान', 'राष्ट्रान', 'एवं', 'राष्ट्रीय', 'ध्वज', 'का', 'सम्मान', 'स्वतत्रता', 'सेनानियों', 'का', 'सम्मान', ',', 'परिवार', 'संरक्षण', 'तथा', 'पशुओं', 'एव', 'जोक', 'जंतुओं', 'के', 'प्रति', 'कतंव्य', 'दायित्व', 'के', 'पालन', 'पर', 'जोर', 'दिया', 'गया', 'है।', 'यहां', 'पौधरोषण', 'भी', 'किया', 'गया', 'पर', 'जिला', 'इस', '.', 'अवसर', 'न्यायाधीश', 'एवं', 'विधिक', 'सेवा', 'के', 'सचिव', 'सहित', 'ज्यायाधीशशणण', 'एवं', 'निजी', 'संस्थान', 'के', 'पदाधिकारी', 'भी', 'उपस्थित', 'रहे', '.', 'पुरस्कार', 'हेतु', 'प्रस्ताव', 'भेजे', 'छतरपुर।', 'मप्र', ',', 'शासन', 'के', 'सामान्य', 'प्रशासन', 'विभाग', 'द्वारा', 'स्व', '.', 'देवीप्रसाद', 'शम्ा', 'वर्ष', '2027', '22', 'के', 'पुरस्कार', 'हेतु', 'शासकोय', 'विभागों', 'से', 'प्रस्ताव', 'भेजने', 'की', 'अपील', 'कौ', 'गईं', 'है।', 'कार्यालय', 'प्रमुख', '।0', 'अगस्त', 'तक', 'जानकारी', 'टें', 'सकेंगे', 'आबेदक', 'चत्', 'श्रेणी', 'कर्मचारी', 'द्वारा', '0।', 'अप्रैल', '202', ')', 'से', '3।', 'मार्च', '2022', 'तक', 'किये', 'गए', 'उत्कृष्ट', 'कार्यों', 'के', 'लिये', 'राज्य', 'स्तरीय', 'पुरस्कार', 'दिया', 'जायेगा', '>', 'दमोह', '“', 'छतरपुर', '«', 'टीकमगढ़', '*', 'पन्\u200dना', 'तहसौलदार', 'रैलेन्द्र', 'बेडोनिया', 'सहित', 'अन्य', 'अधिकारी', 'उपस्थित', 'रहे।', 'प्राप्त', 'जानकारी', 'के', 'अनुसार', 'नगरपालिका', 'परिषद', 'नर्मदापुरम', 'की', 'मतगणना', 'के', 'घोषित', 'परिणामों', 'के', 'अनुसार', 'वार्ड', 'क्रमांक', '!', 'से', 'भाजपा', 'की', 'हिल्या', 'बैनकुपार', 'किया', 'गया', 'नगरीय', 'निकायों', 'के', 'आम', 'निर्वाचन', 'वर्ष', '2022', 'की', 'मतगणना', 'के', 'परिणाम', '20', 'जुलाई', 'को', 'सामने', 'आ', 'गये', 'हैं।', 'कलेक्टर', 'एवं', 'जिला', 'निवांचन', 'अधिकारी', 'नीरज', 'कुमार', 'सिंह', 'ने', 'मतगणना', 'केंद्र', 'होम', 'साइंस', 'कॉलेज', 'में', 'सभी', 'बिजेता', 'प्रत्याशियों', 'को', 'प्रमाण', 'पत्र', 'वितरित', 'किए।', 'कलेक्टर', 'श्री', 'सिंह', 'ने', 'जिस्तरीय', 'पंचायत', 'एवं', 'नगरीय', 'निकाय', 'निर्वाचन', 'के', 'सुचारू', 'एवं', 'सफल', 'संचालन', 'के', 'लिए', 'निर्वाचन', ...
#
# --- Detected Language ---
# hi

# %%
# Image Processing and Text Storing

import cv2
from PIL import Image
import pytesseract
import nltk
from langdetect import detect
import os

nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize

def preprocess_image(image_path):
    # Load the image using OpenCV
    image = cv2.imread(image_path)

    # Convert to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Resize
    gray = cv2.resize(gray, (gray.shape[1] * 2, gray.shape[0] * 2))

    # Denoise
    denoised = cv2.fastNlMeansDenoising(gray, h=30)

    # Save and return path
    temp_path = "processed.png"
    cv2.imwrite(temp_path, denoised)
    return temp_path

def extract_text(image_path):
    processed = preprocess_image(image_path)
    text = pytesseract.image_to_string(Image.open(processed), lang='hin')
    return text.strip()

def normalize_text(text):
    return text.lower().strip()

def tokenize_text(text):
    return word_tokenize(text)

def detect_language(text):
    try:
        return detect(text)
    except:
        return "Could not detect"

def save_output(text, tokens, lang):
    with open("output.txt", "w", encoding='utf-8') as f:
        f.write("== Extracted Text ==\n")
        f.write(text + "\n\n")
        f.write("== Tokens ==\n")
        f.write(" | ".join(tokens) + "\n\n")
        f.write(f"== Detected Language: {lang} ==\n")

image_path = "/content/input/page3.jpg"

# Full Pipeline
text = extract_text(image_path)
normalized = normalize_text(text)
tokens = tokenize_text(normalized)
language = detect_language(normalized)

# Output to Console
print("Extracted Text:\n", text)
print("\nTokens:", tokens)
print("\nDetected Language:", language)

# Save to File
save_output(text, tokens, language)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Extracted Text:
#  नाईंदुनिगय्या
#
# 0वीं की परीक्षा के लिए विद्यार्थी कर
# सकेंगे तीन भाषा विषय का चयन
#
# खण्डबा। माध्यमिक शिक्षा मंढल द्वारा
# शिक्षण सत्र 2022 23 कौ हाई स्कूल परीक्षा
# के लिए विद्यार्थी को निर्धारित भाषा विषयों में
# से कोई तौन विषय का चयन करना होगा।
# नेशनल स्किल क्लालीफिकेशन फेमवर्क विषय
# का चयन करने बाले विद्यार्थियों को निर्धारित
# भाषा विषयों में से कोई दो भाषा विषय का
# चयन करना होगा। चिल्ड्ुन बिथ स्पेशल नीड़
# के विद्यार्थी गणित अथवा विज्ञान के स्थान पर
# चित्रकला अथवा गायन बादन अथवा तबला
# पखावज अथवा कम्प्यूटर विषय में से कोई
# एक विषय ले सकेंगे। साथ ही ऐसे परीक्षार्थियों
# को तौन भाषा विषय में से दो भाषा विषय में
# छूट प्रदान कौ गईं है। ऐसे परीक्षार्थी किसी एक
# भाषा विषय का चयन कर सकेंगे। इस संबंध
# में निर्देश जारी कर दिए गए हैं। माध्यमिक
# शिक्षा मंडल द्वारा मान्यता प्राप्त संस्थाओं में
# नियमित प्रवेश के लिए प्रवेश संबंधी
# मार्गदर्शिका पुस्तिका भी जारी कौ गईं है।
#
# साक्षरता एवं जागरूकता
# शिविर संपन्न
#
# छतरपुर। छतरपुर शहर के नौगांब रोड
# स्थित एक निजि संस्थान में जिला विधिक
# साक्षरता एबं जागरूकता शिविर प्रधान जिला
# न्यायाधीश इृदेश श्रीवास्तव कौ उपस्थिति में
# बुधवार को संपन्न हुआ। इस अबसर पर
# उन्होंने कहा कि भारतौय संविधान में मूल
# अधिकार एवं कतंव्य बताये गये है। नागरिक
# देश के प्रति मौलिक कर्तव्य का पालन करें।
# संविधान में समानता का अधिकार. स्वतंत्रता
# का अधिकार तथा अभिव्यक्ति कौ स्वतंत्रता
# शोषण के विरुद्ध अधिकार. धर्म, संस्कृति
# एबं शिक्षा का अधिकार दिया गया है।
# नागरिकों कर्तव्य में संविधान, राष्ट्रगान एवं
# राष्ट्रीय ध्वज का सम्मान, स्वतंत्रता सेनानियों
# का सम्मान, परिवार संरक्षण तथा पशुओं एवं
# जीव जंतुओं के प्रति करतंव्य दायित्व के
# पालन पर जोर दिया गया है। यहां पौधरोपण
# भी किया गया। इस अबसर पर जिला
# न्यायाधीश एवं विधिक सेवा के सचिव सहित
# न्‍्यायाधीशशण एबं निजौ संस्थान के
# पदाधिकारी भी उपस्थित रहे।
#
# पुरस्कार हेतु प्रस्ताव भेजे
#
# छतरपुर। म प्र शासन के सामान्य प्रशासन
# विभाग द्वारा स्व॒देवौप्रसाद शर्मा ब्ष 202
# 22 के पुरस्कार हेतु शासकोय विभागों से
# प्रस्ताव भेजने कौ कौ गईं है। कार्यालय
# प्रमुख ॥0 अगस्त तक जानकारी दें सकेंगे।
# आबेदक चतुर्थ श्रेणी कर्मचारी द्वारा 0॥ अप्रैल
# 202। से 3 मार्च 2022 तक किये गए उत्कृष्ट
# कार्यों के लिये राज्य स्तरीय पुरस्कार दिया
# जायेगा।
#
#
#
# #दमोह ७छतरपुर७टीकमगढ़«पन्ना
#
# ७खंडवा *हरदा *होशंगाबाद«बैतूल/सारणी/मुलताई
#
# सागर, 2। जुलाई 2022
#
# भाजपा 23, कांग्रेस 5 और निर्दलीय 5 वार्डों में विजयी रहे
#
# शांतिपूर्ण तरीके से चुनाव की कार्यवाही पूर्ण
#
#
#
# नर्मदापुरम।
#
# नगरीय निकायों के आम निर्वाचन
# बर्ष 2022 की मतगणना के परिणाम
# 20 जुलाई को सामने आ गये हैं।
# कलेक्टर एवं जिला निवांचन
# अधिकारी नीरज कुमार सिंह ने
# मतगणना केंद्र होम साइंस कॉलेज में
# सभी विजेता प्रत्याशियों को प्रमाण पत्र
# वितरित किए।
#
# कलेक्टर श्री सिंह ने त्रिस्तरीय पंचायत
# एबं नगरीय निकाय निर्वाचन के सुचारू
# एवं सफल संचालन के लिए निर्वाचन
# कार्य में जुटे समस्त राजस्व , पुलिस सहित
# अन्य संबंधित विभागों के अधिकारी/
# कर्मचारी को उनकी सक्रीय भूमिका के
# लिए बधाई दी और उनके कार्यों की
# सराहना की। इस दौरान पुलिस अधीक्षक
# डॉ गुरकरण सिंह , जिला पंचायत सीईओ
# श्री मनोज सरियाम, अपर कलेक्टर श्री
# मनोज सिंह ठाकुर , ठप जिला निर्वांचन
#
# अधिकारी श्रीमती मोहिनी शर्मा,
#
# नवनिर्वाचित भाजपा पार्षदों का स्वाजत
# छ
#
# बड़वाह नगरपालिका में +.
# इस बार भाजपा की परिषद
#
# तहसीलदार शैलेन्द्र बेडोनिया सहित अन्य
# अधिकारी उपस्थित रहे। प्राप्त जानकारी के
# अनुसार नगरपालिका परिषद नर्मदापुरम
# की मतगणना के घोषित परिणामों के
# अनुसार वार्ड क्रमांक । से भाजपा की
# शिल्पा तेजकुमार गौर को विजेता घोषित
# किया गया हैं।
#
# इसी तरह से वार्ड 2 से भाजपा की
# नयना प्रमोद सोनी, बार्ड 3 से कांग्रेस
# की लीला बसंत सैनी, वार्ड 4 से भाजपा
# की सबक पूनम मेषकर, वार्ड 5 से
# कांग्रेस की दीपिका कुलदीप राठौर, वार्ड
# 6 से भाजपा के राजेन्द्र उपाध्याय, बार्ड
# 7 से भाजपा के अभय वर्मा, वार्ड 8 से
# भाजपा की रिचा जितू तिवारी, वार्ड 9 से
# भाजपा की आरती लक्ष्मण बैस, वार्ड 0
# से भाजपा के दौलतराम यादव, वार्ड
# से निर्दलीय प्रत्याशी गणेश बाबरिया,
# वार्ड 72 से भाजपा की पा मालवीय,
# वार्ड 33 से भाजपा की वर्षा भंडारी, वार्ड
# 34 से भाजपा की प्रेमा पंकज पांडे,
# बार्ड 5 से भाजपा की निर्मला हंसराय,
#
# ॥ ४४
#
# वार्ड ॥6 से भाजपा के प्रकाश नारायण
#
# दमोह। नगरीय निकाय निर्वाचन 2022
# के तहत दूसरे चरण की मतगणना आज
# हटा, पटेरा एवं 5 हु" खेड़ा में निर्धारित
# स्थलों पर संपन्न हुई। अपने निर्धारित
# समय पर एसडीएम एवं रिटर्निंग आफिसर
# अभिषेक सिंह ठाकुर एवं प्रेक्षक
# अनंतनारायण अरोरा तथा जनप्रतिनिधियों
# की उपस्थिति में स्ट्रांग रूम की सील
#
# गौर मामा, वार्ड 77 से भाजपा की नीतू ख़ुलवाई। इस दौरान सहायक रिटर्निंग
#
# यादव, वार्ड ॥8 से कांग्रेस की मीना
# वर्मा, वार्ड ॥9 से कांग्रेस के अनोखेलाल
# राजोरिया, वार्ड 20 से भाजपा के संदीप
# सिंह गज वा ठाकुर, वार्ड 2) से भाजपा की
# महिमा गौर, बार्ड 22 से निर्दलीय
# प्रत्याशी संतोष उपाध्याय, वार्ड 23 से
# निर्दलीय प्रत्याशी चंद्रमोहन सिंह परिहार
# बंटी, वार्ड 24 से भाजपा की संध्या
# अशोक कुशराम, बार्ड 25 से भाजपा के
# कुमार चौधरी, वार्ड 26 से भाजपा
# पलक गौर, वार्ड 27 से भाजपा की
# बिदिंया मांझी, वार्ड 28 से भाजपा की
# कंचन चौकसे सेठी, वार्ड 29 से कांग्रेस
# की सुषमा खत्री, वार्ड 30 से निर्दलीय
# प्रत्याशी रेखा यादव, वार्ड 3) से भाजपा
# के नरेन्द्र पटेल, वार्ड 32 से निर्दलीय
# प्रत्याशी सिमरन अभिषेक रैकवार एवं
# बार्ड 33 से भाजपा की बंदना विमल
# हिल को विजय घोषित किया गया
# ॥
#
# नगर परिषद
# सात भाजपा के
# है, कांग्रेस के पास 06पार्षद
#
# आफिसर तथा संबंधित अधिकारियों
# सहित एसडीओपी बीरेन्द्र बहादुर सिंह भी
# मौजूद थे। एसडीएम एबं रिटर्निंग
# आफिसर अभिषेक सिंह ठाकुर और
# प्रेक्षक अनंतनारायण अरोरा ने सबसे पहले
# पोस्टल बैलेट की गणना का कार्य प्रारंभ
#
# विजयी प्रत्याशियों को
# प्रमाण पत्र वितरित
#
# दमोह। तेंदूखेड़ा रिटर्निंग
# ऑफिसर अविनाश रावत ने
# विजयी प्रत्याशियों को प्रमाण
# पत्र वितरित किये। इसी प्रकार
# पटेरा रिटर्निंग. ऑफिसर
# जानकी उईके ने विजयी
# प्रत्याशियों को प्रमाण पत्र
# वितरित किये। हटा में रिर्टनिंग
# ऑफीसर अभिषेक सिंह ठाकुर
# ने प्रमाण पत्र वितरित किए।
#
#
#
# नाव मे
# जीते
#
# कु बकरे हा
#
# बीजेपी के 7 कांग्रेस के 6 और 2 निर्दलीय पार्षद जीते
#
# कामयाब हुये है उनके
# मोबाईल बन्द हो गये है । सूत्र
# बताते है कि कांग्रेस नेता तथा
# नगर परिषद चुनाव मे कांग्रेस
# की ओर से नेतृत्व कर रहे है
#
# कराया, तदोपरांत स्ट्रांग रूम से ईव्हीएम
# गणना कक्षों में पहुचने उपरांत मतगणना
# प्रांभ हुईं। इस अवसर पर अपर
# कलेक्टर नाथूराम गौड़ ने भी एडीशनल
# एसपी शिव कुमार सिंह के साथ मतगणना
# स्थल पहुंचकर जायजा लिया और
# मतगणना कार्य की सराहना कौ। इस
# अबसर पर उप जिला निर्वाचन अधिकारी
# नाथूराम गांड, एसडीएम एवं रिटनिंग
# अधिकारी अभिषेक सिंह ठाकुर,
# एडीशनल पुलिस अधीक्षक शिवकुमार
# सिंह, एसडीओपी पुलिस बीरेन्द्र बहादुर
# सिंह, टीआई एच आर पांडे , तहसीलदार
# विकास जैन सहित अन्य अधिकारी मौजूद
# ॥
#
#
#
# सकते है । अनुमान लगाया
# जा रहा है कि कांग्रेस को
# निर्दलीयों का साथ मिला तथा
# बडी राजनीतिक डील हुईं तो
# कांग्रेस यहां अपने मंसूबों मे
#
# बनेगी। यह भाजपा
# कार्यकर्ताओं की जीत है। ये
# बातें विधायक सचिन
# बिरला ने बुधवार को
# समीक्षा बैठक में कहीं।
# बैठक में स्थानीय निकाय ,
# चुनाव में भाजपा
# नवनिर्वाचित नौ पार्षदों और
# सभी भाजपा प्रत्याशियों का विधायक
# एवं पार्टी पदाधिकारियों ने भाजपा
# कार्यालय में स्वागत किया।
#
# विधायक ने विजयी भाजपा
# प्रत्याशियों को बधाई दी और कहा कि
#
# के 5६
#
# बढ़ें। विधायक ने भाजपा कार्यकर्ताओं
# व मतदाताओं के प्रति आभार व्यक्त
# किया बैठक में भाजपा नेता
# चंद्रपालसिंह तोमर,लादूराम साहू,
# सुरेंद्र पंडया,जितेंद्र सुराणा, महेंद्रसिंह
# भाटिया, सीटू राजपाल,महेंद्र अमई,
#
#
#
# विजयवर्गीय, मोहन जायसबाल ने
# भाजपा उम्मीदवारों के चुनाव प्रचार में
# तन-मन-धन से जुटे भाजपा
# कार्यकर्ताओं के परिश्रम की प्रशंसा
# की और उन्हें भाजपा की जीत का श्रेय
# दिया। इस अवसर पर बड़ी संख्या में
#
# है दो निर्दलीय जीतने मे
# कामयाब हुये है । नगर परिषद
#
# 3 किसी दल को
# नहीं ऐसे मे परिषद मे
# अध्यक्ष पद पर किसकी
# 'ताजपोशी होगी उसको लेकर
# दिन भर कयास बाजी चलती
# रही ।
#
# परिषद मे भाजपा की
# परिषद को सत्तासीन कराने के
# लिये भाजपा नेताओ ने दावे
# किये इस बीच बडी खबर
# मिली है कि दोने निर्दलीय
#
# उत्तमपालसिह ने कांग्रेस की
# परिषद काबिज कराने के लिये
# कम पार्षद के बावजूद द
# राजनीतिक उलटफेर
# तैयारी कर ली है बताया जाता
# है कि कांग्रेस के जीतने वाले
# पार्षदों को अज्ञात स्थान पर
# ले जाया गया है ।
#
# निर्दलीय पार्षद धम्मु
# राठौर ओर आशीष गोरख
# जोन्टी के मोबाईल बन्द हो
# जाने से यह कयास लगाये जा
# रहे है कि वे नगर परिषद मे
#
# सफल हो सकती है ।
#
# अभी दोनो निर्दलीय
# प्रत्याशियों के कांग्रेस के सम्पर्क
# मे होने की पुष्टि नहीं हुई है
# लेकिन कांग्रेस पार्षदों के अज्ञात
# स्थान पर जाने तथा दो निर्दलीय
# प्रत्याशियों के भी अज्ञात स्थान
# पर जाने की खबर सामने आने
# के बाद यह माना जारहा है कि
# भाजपा के साथ यहां कोई खेल
# हो सकता है ।भाजपा नेतृत्व ने
# समय रहते अपनी तगडी
# रणनीति नहीं बनाईतो परिणाम
#
# जय- पराजय होती रहती है,बढ़ा दिल
# रखते हुए सबको साथ में लेकर आगे
#
# निखिलेश खंडेलवाल,नरहरि दांगी,
# ब्रजेंद्र जोशी,मिद्वू भाटिया,रोमेश
#
# उपस्थित थे।
#
# पावर प्लांट हाइंडिल सोलर पैनल और ख़दान की मिलेगी सौजात
#
# सारणी। पायाल्लेड़ा |
#
# विद्युत नगरी सारनी में नई इकाई और वेस्टर्न
# कोलफील्ड लिमिटेड पाथाखेड़ा में है 2४
# खदान की तैयारी लगभग पूर्ण हो चुकी है और
# दोनों ही औद्योगिक क्षेत्र में जल्द ही उद्योग की
# स्थापना की जाएगी,यह बात भारतीय जनता पार्टी
# के आमला विधानसभा क्षेत्र के विधायक डॉ
# योगेश पंडाग्रे ने बताया उन्होंने कहा कि प्रदेश के
# मुख्यमंत्री शिवराज सिंह चौहान के पास उन के
# माध्यम से अनेकों बार जाकर मुलाकात की गई
# है और उन्होंने आश्वस्त किया है कि विद्युत नगरी
# सारनी में पाबर प्लांट सोलर पैनल और हायडर
# यह तीनों लगेंगे इससे स्थानीय युवाओं को
# रोजगार के संसाधन मिलेंगे इसके अलाबा उन्होंने
# कहा कि वेस्टर्न कोलफील्ड लिमिटेड पाथाखेड़ा
# की भूमिगत खदान के मार्ग की निविदा निकाली
# जा चुकी है मूल्यांकन में अधिक होने के कारण
# दूसरी बार फिर निविदा निकाली गई है जल्द ही
# खदान कौ सौगात भी क्षेत्रवासियों को मिलेगी
# उन्होंने कांग्रेस को आड़े हाथ लेते हुए कहा कि
# कांग्रेस विकास के कार्यों में व्यवधान उत्पन्न करने
#
# का कार्य करती है किसी समय में सुखाढाना
# औद्योगिक क्षेत्रों को सेल्फी प्वाइंट कहा करते थे
# वर्तमान समय में लगभग 85 प्रतिशत औद्योगिक
# क्षेत्र का निर्माण कार्य किया जा चुका है और अब
# ऐसी स्थिति में कांग्रेस के पदाधिकारियों के
# माध्यम से औद्योगिक क्षेत्र का निरीक्षण किया जा
# रहा है इससे यह प्रतीत होता है कि भाजपा के
# माध्यम से क्षेत्रवासियों को कही गई बात सार्थक
# सिद्ध हो रही है।
#
# विकास कार्य का श्रेय लेने वालों की लगी
# हो होडः नगर पालिका परिषद सारनी के अंतर्गत
# दो औद्योगिक क्षेत्र आते हैं और इन दोनों
# औद्योगिक क्षेत्रों में उद्योग स्थापित किए जाने को
# लेकर भारतीय जनता पार्टी के माध्यम से हर संभव
# प्रयास करने का कार्य किया गया है जैसे ही क्षेत्र
# में विकास के कार्य होने पर गति और मोहर लगने
# का कार्य शुरू कम है बैसे ही श्रेयचंद लोगों की
# बाढ़ सी आ गईं है। ऐसी स्थिति में विकास का
# कार्य मे व्यवधान करना ठीक कार्य नहीं है क्षेत्र में
# जन चर्चा का विषय बाना है कि सामाजिक
# संगठनों की आड़ में कुछ दलगत राजनीति करने
# बाले लोग धरना प्रदर्शन और हड़ताल करने की
#
# चेतावनी देने के अलावा नागपुर से घोड़ाडोंगरी
# रेलबे मार्ग को रोकने की भी तैयारी कर रहे हैं इन
# सभी कार्य में प्रत्यक्ष अप्रत्यक्ष रूप से सत्ता पक्ष के
# कई लोग शामिल है ऐसी स्थिति में इस हड़ताल
# को किस दृष्टि से देखा जाएगा इसको लेकर क्षेत्र
# में बहस का मु छिड़ गया है क्षेत्र में रोजगार के
# संसाधन नहीं है व्यापार समाप्त की ओर है। शहर
# से पलायन का दौर जारी है लेकिन ऐसे में हड़ताल
# धरना प्रदर्शन करके रोजगार स्थापित कर पाना भी
# संभव नहीं दिखाई दे रहा है इसकी पूर्व में एक
# दिवसी सफलतम हड़ताल की गई थी लेकिन
# इसके सकारात्मक प्रभाव अब दिखने लगे।
# एनटीपीसी को भगाने बाले लोग भी
# हड़ताल को दे रहे हैं सबसे ज्यादा हवा:
# नगरी सारनी में बर्ष 202-3 एनटीपीसी
# मध्य प्रदेश पावर जेनरेटिंग कंपनी के ज्वाइंट
# बेंचर के माध्यम से सारनी में इकाई स्थापित
# करने की योजना तैयार की गईं थी लेकिन कांग्रेस
# के कई जिम्मेदार नेता एबं मध्यप्रदेश पावर
# जेनरेटिंग कंपनी में श्रमिक संगठन की नेतागिरी
# करने वाले अधिकारी के माध्यम से इसका
# जमकर विरोध किया गया था।
#
# भाजपा पदाधिकारी ब कार्यकर्ता
#
# पार्षद जो भाजपा
# होकर
#
# चुनाव जीतने मे
#
# के बागी भाजपा की परिषद
#
# काबिज होने में रोडा
#
# के उसके आअरमानों पर पानी फेर
# बन सकते है।
#
# काटकूट फाटे से वन विभाज ने आरकाट की
# लकड़ी से भरा पिकअप वाहन जब्त किया
#
# बड़वाह। वन विभाग द्वारा
# आरकाट( नीम एवं आम) की लकड़ी
# का अवैध रूप से परिवहन करते हुए
# एक पिकअप वाहन को पकड़ है।यह
# पिकअप बाहन नगर से करीब 3
# किमी दूर काटकूट फाटे पर स्थित
# एक डेरी पर लकड़ी खाली करने जा
# रही थी।इसी वनकर्मी पहुंचे एवं
# लकड़ी सहित बाहन को जब्त किया
# है।
#
# बन विभाग ने इस मामले में दो
# लोगो पर प्रकरण भी दर्ज किया है।
# रेंजर डीएस राठौड़ ने बताया की
# मुखबिर से सूचना मिली थी की एक
# पिकअप बाहन अवैध रूप से लकड़ी
# का परिवहन कर कप हुक है सुचना पते ही
# मौके पर पहुंचे बनकर्मियो ने देखा
# की एक काटक्ूट फाटे पर स्थित डेरी
# पर पिकअप बाहन क्रमांक एमपी ॥0
# जी 2943 खड़ा है।चालक के पास
#
#
#
# परिवहन सम्बन्धित दस्तावेज नहीं
# मिले यही कारण है कौ पिकअप
# वाहन को जब्त कर बड़वाह
# बनमण्डल कार्यालय लाया
# गया बाहन में रखी गई 350 कीमत
# की करीब डेढ़ चट्टा लकड़ी को भी
# जब्त कर लिया है।इस मामले में
# विभाग ने बाहन मालिक रमेश पिता
# रतन निवासी बलम बुजुर्ग एवं लकड़ी
#
#
#
# बेचने वाले रूपचंद पिता नरसिंह
# निवासी बेलम के खिलाफ
# प्रकरण दर्ज कक दोनों के पास
# कटाई की परमिशन भी नहीं थी।बन
# विभाग से प्राप्त जानकारी के अनुसार
#
# पुर निर्भय के खेत से आम के पेड़
#
# लकड़ी लेकर आए एवं सियाराम
# गोविन्द के खेत से नीम के पेड़
# लकड़ी लेकर आए।
#
# हर घर तिरंगा अभियान शिक्षा व्यवस्था को सुधारने के शासन की सारी कोशिशें नाकाम
# ॥ से 77 अगस्त तक
#
# कलेक्टर संदीप
# जी आर ने बताया कि छतरपुर
# जिले में भी हर घर तिरंगा
# अभियान ॥ से ॥7 अगस्त
# तक जिलेबासियों के सहयोग
# से उत्साहपूर्वक मनाया
# जायेगा।
#
# इस अभियान के माध्यम से
# लोगों में राष्टीय ध्वज के संबंध
# में जागरूकता लाने तथा उनके
# आचरण में देशभक्ति की
# भावना जाग्रत की जायेगी।
# सीईओ जिला पंचायत इस
# अभियान के नोडल अधिकारी
# होंगें। उन्होंने नागरिकों से
# अपील की है कि इस अभियान
# का हिस्सा बने और घरों पर
# ससम्मान राष्ट्रीय ध्वज को
# 'फहराये।
#
# इसी के साथ नागरिक भी
# राष्ट्रीय ध्वज बनाकर न सिर्फ
# घरों पर फहराये बल्कि समाज
#
# के लोगों तक निःशुल्क वितरण
# भी करें। हर घर तिरंगा
# अभियान को मन बचन और
# कर्म से जोड़े और इससे समाज
# के हर लोगों को जुड़ने की
# अपील भी करें।
#
# इस अभियान को सफल
# बनाने के लिये सभी कार्यालयों
# के अधिकारी - कर्मचारी मैदानी
# अंचलों के राजस्व, पंचायत एवं
# ग्रामीण विकास, नगर पालिका
# एवं नगर परिषदों, शिक्षा,
# स्वास्थ्य, महिला एवं बाल
# विकास, विद्युत मण्डल और
# कृषि अन्य विभाग के
# अधिकारी सक्रिय सहभागिता
# निभाएंगें।
#
# जिले के व्यापारियों,
# उद्यमियों, निजी संस्थाओं से भी
# अपील की गई है कि हर घर
# तिरंगा अभियान का हिस्सा बने
# और एक-दूसरे को घर एवं
# प्रतिष्ठानों पर राष्ट्रीय ध्वज
# 'फहराने के लिये प्रेरित करें।
#
# प्रदेश सरकार शिक्षा विभाग को
# लेकर आये दिन बड़े-बढ़े दावे करती
# है। शिक्षा व्यवस्था को पटरी पर लाने
# के लिए सस्‍कार द्वारा करोड़ों रुपये
# पानी की तरह बहाए जाते है। जिससे
# प्रदेश में निवासरत गरीबों के बच्चे
# सरकारी विद्यालयों में ही पढ़कर निजी
# विद्यालयों की तरह शिक्षा सुविधाएं
# ग्रहण कर सके। इसके लिए सरकार
# द्वारा मुफ्त किताबें, गणबेश और
# मध्यान्ह भोजन बच्चों को उपलब्ध
# कराया जाता है, लेकिन दमोह जिले में
# ऐसे अनेक विद्यालय है। जहां शिक्षकों
# की मनमानी के चलते ऐसे नौनिहालों
# का भविष्य अंधकार में दिख रहा है।
# दरअसल मामला पथरिया ब्लॉक के
# शासकीय प्राथमिक विद्यालय पीपर
# खिरिया विद्यालय का है।जहां
# प्रधानाध्यापक संदीप सोनी विद्यालय
# स्मयछर सार आने की बजाए अपनी
# से आते है और शिक्षकों की
# हनक ऐसी है कि शिक्षकों के आने के
# पूर्व बच्चे विद्यालय पहुंचकर झाड़ू
# लगाकर साफ सफाई करते है।
#
#
#
# बच्चे किताबों की बजाए झाड़ू
# लगाकर शिक्षा ग्रहण कर रहे है।
#
# 'पथरिया ब्लाक के पीपर खिरिया के
# प्राथमिक विद्यालय में पढ़ाई के नाम पर
# बच्चों के साथ जमकर खिलवाड़ किया
# जा रहा है। शिक्षा ग्रहण करने के लिए
# विद्यालय आये बच्चों से झाद्ू लगवाई
# जाती हैं। या यूं कहें तो गलत नहीं होगा
# कि सरकार द्वारा चलाये जा रहे स्वच्छ
# भारत मिशन का असर शिक्षकों पर
# कम बच्चों पर ज्यादा दिख रहा है।
#
# शिक्षक खुद लेट आते हैं: वहीं इन
# हालात को देखते हुए जब गांव के
# ग्रामीणों से बात कौ गयी तो उन्होंने
#
# 8... |
#
# बताया कि प्रधानाध्यापक संदीप सोनी
# खुद ही विद्यालय देर से आते हैं।
# जिससे बच्चें अच्छी शिक्षा से बॉंचित
# है २८ रन हम लोगों को अपने बच्चों
# को जल स्क्लॉं में पढ़ाने के लिए
# सोचना पड़ता है। हम गरीब वर्ग के
# लोगों के पास इतने पैसे नहीं हैं, जिससे
# अपने बच्चों को अच्छी शिक्षा दिलवा
# सके,शासकीय विद्यालय की स्थिति
# किसी से नहीं है। विद्यालय में
# शिक्षक मनमाने समय से आते
# हैं। ताला खोलते हैं, जबकि बच्चे स्कूल
# खुलने के पहले ही परिसर में
# पहुंचकर विद्यालय का इंतजार
#
# करते रहते हैं और जब हम ग्रामीणों
# द्वारा इस बात का विरोध किया जाता है
# तो हमारी बात में कोई ध्यान नहीं देता।
# जब इस संबंध में प्राथमिक शाला पीपर
# खिरिया में पदस्थ प्रधान अध्यापक
# संदीप सोनी बात की गई तो उनके द्वारा
# उल्टा ही सवाल किया गया और उन्होंने
# कहा कि संपूर्ण भारत की प्राथमिक
# शालाओ में कहीं भी भृत्य की
# पदस्थापना नहीं है। मुझे शासन ने शाला
# में शिक्षा देने के लिए पदस्थ किया है
# झाड़ू लगाने के लिए नहीं । और जब
# देश के प्रधानमंत्री, ६ द्वारा झाड़ू
# लगाई जा रही है तो अब में क्‍या ही
#
#
#
# बोलूं, मैं भ्रत्य नहीं हूं। अतः
# प्रधानाध्यापक कि इन शब्दों से साफ
# समझा जा सकता है कि वह अपनी
#
# में कितने मस्त हैं। उन्हें शिक्षा
# शासन से कोई मतलब नहीं है, उन्हें तो
# सिर्फ अपनी तनख्वाह से मतलब है।
#
# इनका है वर रु 2 से बात
# जा हे अगर ऐसा 'यमानुसार
# ०. की जाएगी दे
#
# धर्मेंद्र चौथे ,बीआरसी पथरिया
#
# मैं जांच करवाता हूं ,अगर ऐसा है तो
# कार्यवाही की जाएगी।
#
# एस के मिश्रा ,जिला शिक्षा
#
# अधिकारी दमोह
#
# Tokens: ['नाईंदुनिगय्या', '0वीं', 'की', 'परीक्षा', 'के', 'लिए', 'विद्यार्थी', 'कर', 'सकेंगे', 'तीन', 'भाषा', 'विषय', 'का', 'चयन', 'खण्डबा।', 'माध्यमिक', 'शिक्षा', 'मंढल', 'द्वारा', 'शिक्षण', 'सत्र', '2022', '23', 'कौ', 'हाई', 'स्कूल', 'परीक्षा', 'के', 'लिए', 'विद्यार्थी', 'को', 'निर्धारित', 'भाषा', 'विषयों', 'में', 'से', 'कोई', 'तौन', 'विषय', 'का', 'चयन', 'करना', 'होगा।', 'नेशनल', 'स्किल', 'क्लालीफिकेशन', 'फेमवर्क', 'विषय', 'का', 'चयन', 'करने', 'बाले', 'विद्यार्थियों', 'को', 'निर्धारित', 'भाषा', 'विषयों', 'में', 'से', 'कोई', 'दो', 'भाषा', 'विषय', 'का', 'चयन', 'करना', 'होगा।', 'चिल्ड्ुन', 'बिथ', 'स्पेशल', 'नीड़', 'के', 'विद्यार्थी', 'गणित', 'अथवा', 'विज्ञान', 'के', 'स्थान', 'पर', 'चित्रकला', 'अथवा', 'गायन', 'बादन', 'अथवा', 'तबला', 'पखावज', 'अथवा', 'कम्प्यूटर', 'विषय', 'में', 'से', 'कोई', 'एक', 'विषय', 'ले', 'सकेंगे।', 'साथ', 'ही', 'ऐसे', 'परीक्षार्थियों', 'को', 'तौन', 'भाषा', 'विषय', 'में', 'से', 'दो', 'भाषा', 'विषय', 'में', 'छूट', 'प्रदान', 'कौ', 'गईं', 'है।', 'ऐसे', 'परीक्षार्थी', 'किसी', 'एक', 'भाषा', 'विषय', 'का', 'चयन', 'कर', 'सकेंगे।', 'इस', 'संबंध', 'में', 'निर्देश', 'जारी', 'कर', 'दिए', 'गए', 'हैं।', 'माध्यमिक', 'शिक्षा', 'मंडल', 'द्वारा', 'मान्यता', 'प्राप्त', 'संस्थाओं', 'में', 'नियमित', 'प्रवेश', 'के', 'लिए', 'प्रवेश', 'संबंधी', 'मार्गदर्शिका', 'पुस्तिका', 'भी', 'जारी', 'कौ', 'गईं', 'है।', 'साक्षरता', 'एवं', 'जागरूकता', 'शिविर', 'संपन्न', 'छतरपुर।', 'छतरपुर', 'शहर', 'के', 'नौगांब', 'रोड', 'स्थित', 'एक', 'निजि', 'संस्थान', 'में', 'जिला', 'विधिक', 'साक्षरता', 'एबं', 'जागरूकता', 'शिविर', 'प्रधान', 'जिला', 'न्यायाधीश', 'इृदेश', 'श्रीवास्तव', 'कौ', 'उपस्थिति', 'में', 'बुधवार', 'को', 'संपन्न', 'हुआ।', 'इस', 'अबसर', 'पर', 'उन्होंने', 'कहा', 'कि', 'भारतौय', 'संविधान', 'में', 'मूल', 'अधिकार', 'एवं', 'कतंव्य', 'बताये', 'गये', 'है।', 'नागरिक', 'देश', 'के', 'प्रति', 'मौलिक', 'कर्तव्य', 'का', 'पालन', 'करें।', 'संविधान', 'में', 'समानता', 'का', 'अधिकार', '.', 'स्वतंत्रता', 'का', 'अधिकार', 'तथा', 'अभिव्यक्ति', 'कौ', 'स्वतंत्रता', 'शोषण', 'के', 'विरुद्ध', 'अधिकार', '.', 'धर्म', ',', 'संस्कृति', 'एबं', 'शिक्षा', 'का', 'अधिकार', 'दिया', 'गया', 'है।', 'नागरिकों', 'कर्तव्य', 'में', 'संविधान', ',', 'राष्ट्रगान', 'एवं', 'राष्ट्रीय', 'ध्वज', 'का', 'सम्मान', ',', 'स्वतंत्रता', 'सेनानियों', 'का', 'सम्मान', ',', 'परिवार', 'संरक्षण', 'तथा', 'पशुओं', 'एवं', 'जीव', 'जंतुओं', 'के', 'प्रति', 'करतंव्य', 'दायित्व', 'के', 'पालन', 'पर', 'जोर', 'दिया', 'गया', 'है।', 'यहां', 'पौधरोपण', 'भी', 'किया', 'गया।', 'इस', 'अबसर', 'पर', 'जिला', 'न्यायाधीश', 'एवं', 'विधिक', 'सेवा', 'के', 'सचिव', 'सहित', 'न्\u200d्यायाधीशशण', 'एबं', 'निजौ', 'संस्थान', 'के', 'पदाधिकारी', 'भी', 'उपस्थित', 'रहे।', 'पुरस्कार', 'हेतु', 'प्रस्ताव', 'भेजे', 'छतरपुर।', 'म', 'प्र', 'शासन', 'के', 'सामान्य', 'प्रशासन', 'विभाग', 'द्वारा', 'स्व॒देवौप्रसाद', 'शर्मा', 'ब्ष', '202', '22', 'के', 'पुरस्कार', 'हेतु', 'शासकोय', 'विभागों', 'से', 'प्रस्ताव', 'भेजने', 'कौ', 'कौ', 'गईं', 'है।', 'कार्यालय', 'प्रमुख', '॥0', 'अगस्त', 'तक', 'जानकारी', 'दें', 'सकेंगे।', 'आबेदक', 'चतुर्थ', 'श्रेणी', 'कर्मचारी', 'द्वारा', '0॥', 'अप्रैल', '202।', 'से', '3', 'मार्च', '2022', 'तक', 'किये', 'गए', 'उत्कृष्ट', 'कार्यों', 'के', 'लिये', 'राज्य', 'स्तरीय', 'पुरस्कार', 'दिया', 'जायेगा।', '#', 'दमोह', '७छतरपुर७टीकमगढ़', '«', 'पन्ना', '७खंडवा', '*', 'हरदा', '*', 'होशंगाबाद', '«', 'बैतूल/सारणी/मुलताई', 'सागर', ',', '2।', 'जुलाई', '2022', 'भाजपा', '23', ',', 'कांग्रेस', '5', 'और', 'निर्दलीय', '5', 'वार्डों', 'में', 'विजयी', 'रहे', 'शांतिपूर्ण', 'तरीके', 'से', 'चुनाव', 'की', 'कार्यवाही', 'पूर्ण', 'नर्मदापुरम।', 'नगरीय', 'निकायों', 'के', 'आम', 'निर्वाचन', 'बर्ष', '2022', 'की', 'मतगणना', 'के', 'परिणाम', '20', 'जुलाई', 'को', 'सामने', 'आ', 'गये', 'हैं।', 'कलेक्टर', 'एवं', 'जिला', 'निवांचन', 'अधिकारी', 'नीरज', 'कुमार', 'सिंह', 'ने', 'मतगणना', 'केंद्र', 'होम', 'साइंस', 'कॉलेज', 'में', 'सभी', 'विजेता', 'प्रत्याशियों', 'को', 'प्रमाण', 'पत्र', 'वितरित', 'किए।', 'कलेक्टर', 'श्री', 'सिंह', 'ने', 'त्रिस्तरीय', 'पंचायत', 'एबं', 'नगरीय', 'निकाय', 'निर्वाचन', 'के', 'सुचारू', 'एवं', 'सफल', 'संचालन', 'के', 'लिए', 'निर्वाचन', 'कार्य', 'में', 'जु ...
#
# Detected Language: hi

# %%
# !python -m spacy download xx_ent_wiki_sm
# Out:
# Collecting xx-ent-wiki-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/xx_ent_wiki_sm-3.8.0/xx_ent_wiki_sm-3.8.0-py3-none-any.whl (11.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 61.3 MB/s eta 0:00:00
# Installing collected packages: xx-ent-wiki-sm
# Successfully installed xx-ent-wiki-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('xx_ent_wiki_sm')

# %%
# !pip install nltk spacy indic-nlp-library
# !python -m spacy download xx_ent_wiki_sm
# !pip install pytesseract pillow
# !sudo apt-get install tesseract-ocr
# !sudo apt-get install tesseract-ocr-hin
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.8.5)
# Requirement already satisfied: indic-nlp-library in /usr/local/lib/python3.11/dist-packages (0.92)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.2)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: sphinx-argparse in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.5.2)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (3.0.2)
# Requirement already satisfied: morfessor in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.2.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.1.31)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (8.2.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (0.21.2)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.11/dist-packages (from sphinx-rtd-theme->indic-nlp-library) (4.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting xx-ent-wiki-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/xx_ent_wiki_sm-3.8.0/xx_ent_wiki_sm-3.8.0-py3-none-any.whl (11.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 62.5 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('xx_ent_wiki_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Tagging and Tokenisation
import cv2
import pytesseract
from PIL import Image
from nltk.tokenize import word_tokenize
import spacy
from langdetect import detect
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
from indicnlp.tokenize import indic_tokenize
from nltk import pos_tag
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')

# Custom Basic Hindi Stemmer
def basic_hindi_stemmer(word):
    suffixes = ['ा', 'ी', 'ें', 'ों', 'े', 'ू', 'ो', 'ाएंगे', 'ाना', 'िए', 'ना']
    for suffix in suffixes:
        if word.endswith(suffix):
            return word[:-len(suffix)]
    return word

# Load SpaCy Multilingual NER model
nlp_spacy = spacy.load("xx_ent_wiki_sm")

# Step 1: Load and Preprocess Image
img_path = "/content/input/page3.jpg"  # Update with your image path
img = cv2.imread(img_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)

# Step 2: OCR (Hindi)
custom_config = r'--oem 3 --psm 6 -l hin'
extracted_text = pytesseract.image_to_string(thresh, config=custom_config)
print(" OCR Extracted Text:\n", extracted_text)

# Step 3: Normalization
factory = IndicNormalizerFactory()
normalizer = factory.get_normalizer("hi")
normalized_text = normalizer.normalize(extracted_text)
print("\n Normalized Text:\n", normalized_text)

# Step 4: Tokenization
tokens = list(indic_tokenize.trivial_tokenize(normalized_text, lang='hi'))
print("\n Tokens:\n", tokens)

# Step 5: Stemming
stemmed_tokens = [basic_hindi_stemmer(tok) for tok in tokens]
print("\n Stemmed Tokens (Basic):\n", stemmed_tokens)

# Step 6: Lemmatization
doc = nlp_spacy(normalized_text)
lemmatized = [token.lemma_ for token in doc]
print("\n Lemmatized:\n", lemmatized)

# Step 7: POS Tagging (using NLTK for demo)
# Note: This is approximate since NLTK is not Hindi-specific
pos_tags = pos_tag(tokens)
print("\n POS Tags:\n", pos_tags)

# Step 8: Named Entity Recognition (NER)
print("\n Named Entities:\n")
for ent in doc.ents:
    print(f"{ent.text} --> {ent.label_}")

# Step 9: Language Detection
lang = detect(normalized_text)
print(f"\n Detected Language: {lang}")

# Step 10: Basic Summarization
lines = normalized_text.split('\n')
summary = '\n'.join(lines[:3])
print("\n Summary:\n", summary)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
#  OCR Extracted Text:
#  ज्ाईंदुनिया *दमोह *छतरपुरण्टीकमगढ़*्पन्‍ना “खंडवा *हरदा न्होशंगाबाद*्बैतूल/सारणी/मुलताई... धाग्र, गा बुत्ई2० है:
# कांग्रेस
# शव भाजपा 23, कांग्रेस 5 और 5 वार्डो
# सकेंगे तीन भाषा विषय का चयन ५ १ का ही
# मंडल हि पद जुक; हें पक मयंक ॥ ज्ल्कम हि तरीके
# 520 नागा  इवाए ७ फेबुसममका ह्‌ मल £ & हिट वर्ण तरीके से चुनाव की कार्यवाही पूर्ण
# के लिए विद्या को निर्धारित भाषा विषयों मे ६५5 |; 2 न / आ८2 दर 7 ४ ॥ नगतीय निकाय निर्वाचत 2022 कराया, तदोपरांत स्ट्रांग रूम से ईच्हीएम
# से कोई तीन विषय का चयन करना होगा।.| 20.0 मन | हे श 5 आज, पा, पर के तहत दूसरे चरण की मतगणना आज गणना कक्ष यें पहुचने उपरांत घतगणना
# ेशकल स्किल क्लीक्केशत फंसंवक वषय ही ० हैं।. ढ है भ - जज डा ते ये वि बम हु व आप
# आचरण में देशभक्ति कौ स्वास्थ्य, महिला एवं बाल ऐसे अनेक विद्यालय है। जहां शिक्षकों. पथरिया ब्लाक के पीपर खिरिया के जिससे बच्चें अच्छी शिक्षा से बंचित तो हमारी ब्रात में कोई ध्यान नहीं देता। समझा जा सकता है कि वह अपनी
# भावना जागरत को जायेगी। विकास, विद्युत मण्डल और को मनपानो के चलते ऐसे नौरिहालों प्राथमिक विद्यालय में पढई के शाम पर हैपजबूरन रम लोगों को अपने बल्वों. जब इस संबंध मे आ्रयमिक शाला पीपर से कितने घस्त हं। उल्हे शिक्षा और
# सौईओ जिला पंचायत इस कृषि अन्य विभाग के का भ्रिष्य अभकार में दिख रहा है। बच्चों के साथ जमकर खिलवाड़ किया को प्राइवेट स्कलों में पढ़ाने के लिए खिरिया में पदस्थ प्रधान अध्यापक शासन से कोई महलब नहीं है, उन्हें दो
# अभियान के नोडल अधिकारी अधिकारी सक्रिय सहभागिता... दरअसल मामला पथरिया ब्लॉक के जा रहा है। शिक्षा ग्रण करने के लिए. सोचना पड़ता है। हम गरीब वर्ग के संदीष सोनी बात की गई तो उनके द्वारा. सिर्फ अपनी तनख्याह से मतलब है।
# होंगें। डक्होंने नागरिकों से निभाएंगे। शासकीय प्राथमिक विद्यालय पीषर विद्यालय आये बच्चों से झाड़ू लगवाई लोगों के पास इतने पैसे नहीं हैं, जिससे उल्टा ही सवाल किया गया और उन्होंने
# अपील की है कि इस अभियान जिले के व्यापारियों, खिरिया विद्यालय का है।जहां जाती हैं। या यू कहें तो गलत नहीं होगा अपने बच्चों को अच्छी शिक्षा दिलवा कहा कि संपूर्ण भार की प्राथमिक _ इनका कहना हैः अभी शिक्षक से बात
# का ढिल्‍्ला बने और मरों पर उद्यमियों, निज संस्थाओं से भी अ्धधानाध्यापक संदीप सोनी विधालय कि गरकार हाया चलाये जा रहे स्वच्छ सके शाकौय विद्यालय को रिथिति शालाओ में कहाँ भी भत्य की कराई अगर रा है ते वियानुसा,
# ससम्मान राष्ट्रीय ध्वज को अपील की गई है कि हर घर समयानुसार आने को बजाए अपनी धारत मिशन का असर शिक्षकों पर किसी ये नहीं है। विद्यालय में पदस्थापना नहीं है। मुझे शासन ने शाला को आए बसों पथारेया
# फहराबे। तिरंगा अभिवान का हिस्सा बने. गनमजी से आते है और शिक्षकों की कम बच्चों पर ज्यादा दिख रहा है। .. शिक्षक अपने मनमाने समय से आते में शिक्षा देने के लिए पदस्थ किया है. # जब वन अब जी
# इसी के साथ नागरिक भी और एक-दूसरे को घर एवं हतक ऐसी है कि शिक्षकों के आने के. शिक्षक खुद लेट आते हैं: बहीं इन॒हैं। ताला खोलते हैं,जब्रकि बच्चे स्कूल झाड़ू लगाने के लिए नहीं । और जब कार्यवाही को जाएगी। है
# राष्ट्र, ध्वज बनाकर न सिर्फ प्रतिष्टानों पर राष्ट्रीय ध्यज पूर्ण बच्चे वरिधालय पहुंचकर श्ञाड्ू हालात को देखते हुए जब गांव के खुलने के पहले ही स्कूल परिसर में देश के प्रधानमंत्री,मुख्यमंत्री डरा झाड़ू एस के सिशा /डिला शिक्षा
# घरों पर फहराये बल्कि समाज फहरने के लिये प्रेरित करें। लगाकर साफ सफाई करते है। ग्रामीणों से बात कौ गयी तो उन्होंने पहुंचकर विद्यालय खुलने का इंतजार लगाई जा रही है क्रो अब में क्‍या ही अधिकारी दमोह
#
#
#  Normalized Text:
#  ज्ाईंदुनिया *दमोह *छतरपुरण्टीकमगढ़*्पन्ना "खंडवा *हरदा न्होशंगाबाद*्बैतूल/सारणी/मुलताई... धाग्र, गा बुत्ई2० हैः
# कांग्रेस
# शव भाजपा 23, कांग्रेस 5 और 5 वार्डो
# सकेंगे तीन भाषा विषय का चयन ५ १ का ही
# मंडल हि पद जुक; हें पक मयंक ॥ ज्ल्कम हि तरीके
# 520 नागा  इवाए ७ फेबुसममका ह् मल £ & हिट वर्ण तरीके से चुनाव की कार्यवाही पूर्ण
# के लिए विद्या को निर्धारित भाषा विषयों मे ६५5 ।; 2 न / आ८2 दर 7 ४ ॥ नगतीय निकाय निर्वाचत 2022 कराया, तदोपरांत स्ट्रांग रूम से ईच्हीएम
# से कोई तीन विषय का चयन करना होगा।.। 20.0 मन । हे श 5 आज, पा, पर के तहत दूसरे चरण की मतगणना आज गणना कक्ष यें पहुचने उपरांत घतगणना
# ेशकल स्किल क्लीक्केशत फंसंवक वषय ही ० हैं।. ढ है भ - जज डा ते ये वि बम हु व आप
# का चयन करे वाले विद्यार्थियों को निर्धारित $ हि डे ; * ज्ै स्थलों पर संपन्न हुई। अपने निर्धारित कलेक्टर नाथूग़म गौड़ ने भी एडीशनल
# का चन करे वाले विवि को निया । । 2 कं उसपर एउलीएस एवं रिटनिंग आफिसर. एसपी शिव कुमार सिंह के साथ मतगणना
# चबन करना होगा। चिल्ड़र विध स्पेशल नीड.. । > हू हा का अभिषेक गः आकर एवं प्रेक्षक स्थल पहुंचकर जायजा लिया और
# के विद्यार्थी गणित अथवा विज्ञान के स्थान पर > है -> अनंतनारायण अरोरा तथा जनप्रतिनिधियों मतगणना कार्य को सराहना की। इस
# चित्रकला अथवा गायन बादन अथवा तबला जर्मदापुरम। तहसीलदार शैलेन्र बेडीनिया सहित अन्य वार्ड 6 से भाजपा के प्रकाश नाराण्ण की उपस्थिति में स्ट्रांग रूम कौ सील अबसर पर उए जिला निर्बाचन अधिकारी
# पात्र आधवा कम्यूटर िकय मे से कोई अधिकारी उपस्थित रहे। प्राप्त जानकाती के गौर मामा, वार्ड ॥7 से भाजपा को नीतू खुलवाई। इस दौरान सहायक रिटनिंग ताथुयम गौड़, एसडीएम एवं ऐटिनिंग
# एक विषय ले सकेंगे। साथ ही ऐसे परीक्षार्थियों नगरीस निकायों के आम निर्वाचन अनुसार नगरपालिका परिषद नर्षदापुर्ण यादव, चार्ड 8 से कांग्रेस की भोना आफिसर तथा संबंधित अधिकारियों अधिकारी अभिषेक प्विंह ठाकुर,
# को जीन भाषा लिपय मे से दो भाषा जिषय ये... वर्ष 2022 की मतगणना के परिणाप्र की मतगणना के घोषित परिणामों के वर्मा, वार्ड ॥9 से कांग्रेस के अनोखेलाल सहित एसडीओपी बीरेन््र बहादुर सिं भी एड्रीशनल पुलिस अधीक्षक शिवकुपार
# का ढिल््ला बने और मरों पर उद्यमियों, निज संस्थाओं से भी अ्धधानाध्यापक संदीप सोनी विधालय कि गरकार हाया चलाये जा रहे स्वच्छ सके शाकौय विद्यालय को रिथिति शालाओ में कहाँ भी भत्य की कराई अगर रा है ते वियानुसा,
# ससम्मान राष्ट्रीय ध्वज को अपील की गई है कि हर घर समयानुसार आने को बजाए अपनी धारत मिशन का असर शिक्षकों पर किसी ये नहीं है। विद्यालय में पदस्थापना नहीं है। मुझे शासन ने शाला को आए बसों पथारेया
# फहराबे। तिरंगा अभिवान का हिस्सा बने. गनमजी से आते है और शिक्षकों की कम बच्चों पर ज्यादा दिख रहा है। .. शिक्षक अपने मनमाने समय से आते में शिक्षा देने के लिए पदस्थ किया है. # जब वन अब जी
# इसी के साथ नागरिक भी और एक-दूसरे को घर एवं हतक ऐसी है कि शिक्षकों के आने के. शिक्षक खुद लेट आते हैंः बहीं इन॒हैं। ताला खोलते हैं,जब्रकि बच्चे स्कूल झाड़ू लगाने के लिए नहीं । और जब कार्यवाही को जाएगी। है
# राष्ट्र, ध्वज बनाकर न सिर्फ प्रतिष्टानों पर राष्ट्रीय ध्यज पूर्ण बच्चे वरिधालय पहुंचकर श्ञाड्ू हालात को देखते हुए जब गांव के खुलने के पहले ही स्कूल परिसर में देश के प्रधानमंत्री,मुख्यमंत्री डरा झाड़ू एस के सिशा /डिला शिक्षा
# घरों पर फहराये बल्कि समाज फहरने के लिये प्रेरित करें। लगाकर साफ सफाई करते है। ग्रामीणों से बात कौ गयी तो उन्होंने पहुंचकर विद्यालय खुलने का इंतजार लगाई जा रही है क्रो अब में क्या ही अधिकारी दमोह
#
#
#  Tokens:
#  ['ज्ाईंदुनिया', '*', 'दमोह', '*', 'छतरपुरण्टीकमगढ़', '*', '्पन्ना', '"', 'खंडवा', '*', 'हरदा', 'न्होशंगाबाद', '*', '्बैतूल', '/', 'सारणी', '/', 'मुलताई', '.', '.', '.', 'धाग्र', ',', 'गा', 'बुत्ई2०', 'हैः\nकांग्रेस\nशव', 'भाजपा', '23', ',', 'कांग्रेस', '5', 'और', '5', 'वार्डो\nसकेंगे', 'तीन', 'भाषा', 'विषय', 'का', 'चयन', '५', '१', 'का', 'ही\nमंडल', 'हि', 'पद', 'जुक', ';', 'हें', 'पक', 'मयंक', '॥', 'ज्ल्कम', 'हि', 'तरीके\n520', 'नागा', 'इवाए', '७', 'फेबुसममका', 'ह्', 'मल', '£', '&', 'हिट', 'वर्ण', 'तरीके', 'से', 'चुनाव', 'की', 'कार्यवाही', 'पूर्ण\nके', 'लिए', 'विद्या', 'को', 'निर्धारित', 'भाषा', 'विषयों', 'मे', '६५5', '।', ';', '2', 'न', '/', 'आ८2', 'दर', '7', '४', '॥', 'नगतीय', 'निकाय', 'निर्वाचत', '2022', 'कराया', ',', 'तदोपरांत', 'स्ट्रांग', 'रूम', 'से', 'ईच्हीएम\nसे', 'कोई', 'तीन', 'विषय', 'का', 'चयन', 'करना', 'होगा', '।', '.', '।', '20.0', 'मन', '।', 'हे', 'श', '5', 'आज', ',', 'पा', ',', 'पर', 'के', 'तहत', 'दूसरे', 'चरण', 'की', 'मतगणना', 'आज', 'गणना', 'कक्ष', 'यें', 'पहुचने', 'उपरांत', 'घतगणना\nेशकल', 'स्किल', 'क्लीक्केशत', 'फंसंवक', 'वषय', 'ही', '०', 'हैं', '।', '.', 'ढ', 'है', 'भ', '-', 'जज', 'डा', 'ते', 'ये', 'वि', 'बम', 'हु', 'व', 'आप\nका', 'चयन', 'करे', 'वाले', 'विद्यार्थियों', 'को', 'निर्धारित', '$', 'हि', 'डे', ';', '*', 'ज्ै', 'स्थलों', 'पर', 'संपन्न', 'हुई', '।', 'अपने', 'निर्धारित', 'कलेक्टर', 'नाथूग़म', 'गौड़', 'ने', 'भी', 'एडीशनल\nका', 'चन', 'करे', 'वाले', 'विवि', 'को', 'निया', '।', '।', '2', 'कं', 'उसपर', 'एउलीएस', 'एवं', 'रिटनिंग', 'आफिसर', '.', 'एसपी', 'शिव', 'कुमार', 'सिंह', 'के', 'साथ', 'मतगणना\nचबन', 'करना', 'होगा', '।', 'चिल्ड़र', 'विध', 'स्पेशल', 'नीड', '.', '.', '।', '>', 'हू', 'हा', 'का', 'अभिषेक', 'गः', 'आकर', 'एवं', 'प्रेक्षक', 'स्थल', 'पहुंचकर', 'जायजा', 'लिया', 'और\nके', 'विद्यार्थी', 'गणित', 'अथवा', 'विज्ञान', 'के', 'स्थान', 'पर', '>', 'है', '-', '>', 'अनंतनारायण', 'अरोरा', 'तथा', 'जनप्रतिनिधियों', 'मतगणना', 'कार्य', 'को', 'सराहना', 'की', '।', 'इस\nचित्रकला', 'अथवा', 'गायन', 'बादन', 'अथवा', 'तबला', 'जर्मदापुरम', '।', 'तहसीलदार', 'शैलेन्र', 'बेडीनिया', 'सहित', 'अन्य', 'वार्ड', '6', 'से', 'भाजपा', 'के', 'प्रकाश', 'नाराण्ण', 'की', 'उपस्थिति', 'में', 'स्ट्रांग', 'रूम', 'कौ', 'सील', 'अबसर', 'पर', 'उए', 'जिला', 'निर्बाचन', 'अधिकारी\nपात्र', 'आधवा', 'कम्यूटर', 'िकय', 'मे', 'से', 'कोई', 'अधिकारी', 'उपस्थित', 'रहे', '।', 'प्राप्त', 'जानकाती', 'के', 'गौर', 'मामा', ',', 'वार्ड', '॥', '7', 'से', 'भाजपा', 'को', 'नीतू', 'खुलवाई', '।', 'इस', 'दौरान', 'सहायक', 'रिटनिंग', 'ताथुयम', 'गौड़', ',', 'एसडीएम', 'एवं', 'ऐटिनिंग\nएक', 'विषय', 'ले', 'सकेंगे', '।', 'साथ', 'ही', 'ऐसे', 'परीक्षार्थियों', 'नगरीस', 'निकायों', 'के', 'आम', 'निर्वाचन', 'अनुसार', 'नगरपालिका', 'परिषद', 'नर्षदापुर्ण', 'यादव', ',', 'चार्ड', '8', 'से', 'कांग्रेस', 'की', 'भोना', 'आफिसर', 'तथा', 'संबंधित', 'अधिकारियों', 'अधिकारी', 'अभिषेक', 'प्विंह', 'ठाकुर', ',', '\nको', 'जीन', 'भाषा', 'लिपय', 'मे', 'से', 'दो', 'भाषा', 'जिषय', 'ये', '.', '.', '.', 'वर्ष', '2022', 'की', 'मतगणना', 'के', 'परिणाप्र', 'की', 'मतगणना', 'के', 'घोषित', 'परिणामों', 'के', 'वर्मा', ',', 'वार्ड', '॥', '9', 'से', 'कांग्रेस', 'के', 'अनोखेलाल', 'सहित', 'एसडीओपी', 'बीरेन््र', 'बहादुर', 'सिं', 'भी', 'एड्रीशनल', 'पुलिस', 'अधीक्षक', 'शिवकुपार\n', "'", 'ूट', 'प्रदान', 'की', 'गई', 'है', '।', 'ऐसे', 'परीक्षार्थी', 'किसी', 'एक', '.', '.', '.', '।', '2०', '.', 'जुलाई', 'को', 'साथने', 'आ', 'गये', 'हैं', '।', 'अनुसार', 'वार्ड', 'ऋषांक', '।', 'से', 'भाजपा', 'कौ', 'राजोरिया', ',', 'बार्ड', '20', 'से', 'भाजपा', 'के', 'संदीप', 'मौजूद', 'थे', '।', 'एसडीपम', 'एवं', 'हिट्निंग', 'सिंह', ',', 'एसडीओपी', 'पुलिस', 'बीऐद्र', 'बहादुर\nपा', 'चिपय', 'का', 'चयन', 'कर', 'सके', 'इस', 'सबंध', '.', '.', '.', 'कलेक्टरः', 'एव', 'किला', ',', 'लिवांचन', 'शिलया', 'तनु', 'गौए', 'को', 'विेता', 'घोकित', 'सिर', 'गुल', 'चार', ']', 'से', 'आजा', 'की', 'आकिलर', 'अमिनेक', 'सिंए', 'डा', 'और', '.', 'कि', 'टाई', 'एच', 'जा', 'पे', 'लहलीकबर\nमें', 'निर्देश', 'जाती', 'कर', 'दिए', 'गए', 'हैं', '।', 'परध्यमिक', '।', 'अधिकारी', 'नीरज', 'कुमार', 'सिंह', 'ने', 'किया', 'गया', 'है', '।', 'महिमा', 'हि', 'जौर', ',', 'छार्ड', '22', 'से', 'निर्द ...
#
#  Stemmed Tokens (Basic):
#  ['ज्ाईंदुनिय', '*', 'दमोह', '*', 'छतरपुरण्टीकमगढ़', '*', '्पन्न', '"', 'खंडव', '*', 'हरद', 'न्होशंगाबाद', '*', '्बैतूल', '/', 'सारण', '/', 'मुलताई', '.', '.', '.', 'धाग्र', ',', 'ग', 'बुत्ई2०', 'हैः\nकांग्रेस\nशव', 'भाजप', '23', ',', 'कांग्रेस', '5', 'और', '5', 'वार्डो\nसकेंग', 'तीन', 'भाष', 'विषय', 'क', 'चयन', '५', '१', 'क', 'ही\nमंडल', 'हि', 'पद', 'जुक', ';', 'ह', 'पक', 'मयंक', '॥', 'ज्ल्कम', 'हि', 'तरीके\n520', 'नाग', 'इवाए', '७', 'फेबुसममक', 'ह्', 'मल', '£', '&', 'हिट', 'वर्ण', 'तरीक', 'स', 'चुनाव', 'क', 'कार्यवाह', 'पूर्ण\nक', 'ल', 'विद्य', 'क', 'निर्धारित', 'भाष', 'विषय', 'म', '६५5', '।', ';', '2', 'न', '/', 'आ८2', 'दर', '7', '४', '॥', 'नगतीय', 'निकाय', 'निर्वाचत', '2022', 'कराय', ',', 'तदोपरांत', 'स्ट्रांग', 'रूम', 'स', 'ईच्हीएम\nस', 'कोई', 'तीन', 'विषय', 'क', 'चयन', 'करन', 'होग', '।', '.', '।', '20.0', 'मन', '।', 'ह', 'श', '5', 'आज', ',', 'प', ',', 'पर', 'क', 'तहत', 'दूसर', 'चरण', 'क', 'मतगणन', 'आज', 'गणन', 'कक्ष', 'य', 'पहुचन', 'उपरांत', 'घतगणना\nेशकल', 'स्किल', 'क्लीक्केशत', 'फंसंवक', 'वषय', 'ह', '०', 'हैं', '।', '.', 'ढ', 'है', 'भ', '-', 'जज', 'ड', 'त', 'य', 'वि', 'बम', 'हु', 'व', 'आप\nक', 'चयन', 'कर', 'वाल', 'विद्यार्थिय', 'क', 'निर्धारित', '$', 'हि', 'ड', ';', '*', 'ज्ै', 'स्थल', 'पर', 'संपन्न', 'हुई', '।', 'अपन', 'निर्धारित', 'कलेक्टर', 'नाथूग़म', 'गौड़', 'न', 'भ', 'एडीशनल\nक', 'चन', 'कर', 'वाल', 'विवि', 'क', 'निय', '।', '।', '2', 'कं', 'उसपर', 'एउलीएस', 'एवं', 'रिटनिंग', 'आफिसर', '.', 'एसप', 'शिव', 'कुमार', 'सिंह', 'क', 'साथ', 'मतगणना\nचबन', 'करन', 'होग', '।', 'चिल्ड़र', 'विध', 'स्पेशल', 'नीड', '.', '.', '।', '>', 'ह', 'ह', 'क', 'अभिषेक', 'गः', 'आकर', 'एवं', 'प्रेक्षक', 'स्थल', 'पहुंचकर', 'जायज', 'लिय', 'और\nक', 'विद्यार्थ', 'गणित', 'अथव', 'विज्ञान', 'क', 'स्थान', 'पर', '>', 'है', '-', '>', 'अनंतनारायण', 'अरोर', 'तथ', 'जनप्रतिनिधिय', 'मतगणन', 'कार्य', 'क', 'सराहन', 'क', '।', 'इस\nचित्रकल', 'अथव', 'गायन', 'बादन', 'अथव', 'तबल', 'जर्मदापुरम', '।', 'तहसीलदार', 'शैलेन्र', 'बेडीनिय', 'सहित', 'अन्य', 'वार्ड', '6', 'स', 'भाजप', 'क', 'प्रकाश', 'नाराण्ण', 'क', 'उपस्थिति', 'म', 'स्ट्रांग', 'रूम', 'कौ', 'सील', 'अबसर', 'पर', 'उए', 'जिल', 'निर्बाचन', 'अधिकारी\nपात्र', 'आधव', 'कम्यूटर', 'िकय', 'म', 'स', 'कोई', 'अधिकार', 'उपस्थित', 'रह', '।', 'प्राप्त', 'जानकात', 'क', 'गौर', 'माम', ',', 'वार्ड', '॥', '7', 'स', 'भाजप', 'क', 'नीत', 'खुलवाई', '।', 'इस', 'दौरान', 'सहायक', 'रिटनिंग', 'ताथुयम', 'गौड़', ',', 'एसडीएम', 'एवं', 'ऐटिनिंग\nएक', 'विषय', 'ल', 'सकेंग', '।', 'साथ', 'ह', 'ऐस', 'परीक्षार्थिय', 'नगरीस', 'निकाय', 'क', 'आम', 'निर्वाचन', 'अनुसार', 'नगरपालिक', 'परिषद', 'नर्षदापुर्ण', 'यादव', ',', 'चार्ड', '8', 'स', 'कांग्रेस', 'क', 'भोन', 'आफिसर', 'तथ', 'संबंधित', 'अधिकारिय', 'अधिकार', 'अभिषेक', 'प्विंह', 'ठाकुर', ',', '\nक', 'जीन', 'भाष', 'लिपय', 'म', 'स', 'द', 'भाष', 'जिषय', 'य', '.', '.', '.', 'वर्ष', '2022', 'क', 'मतगणन', 'क', 'परिणाप्र', 'क', 'मतगणन', 'क', 'घोषित', 'परिणाम', 'क', 'वर्म', ',', 'वार्ड', '॥', '9', 'स', 'कांग्रेस', 'क', 'अनोखेलाल', 'सहित', 'एसडीओप', 'बीरेन््र', 'बहादुर', 'सिं', 'भ', 'एड्रीशनल', 'पुलिस', 'अधीक्षक', 'शिवकुपार\n', "'", 'ूट', 'प्रदान', 'क', 'गई', 'है', '।', 'ऐस', 'परीक्षार्थ', 'किस', 'एक', '.', '.', '.', '।', '2०', '.', 'जुलाई', 'क', 'साथन', 'आ', 'गय', 'हैं', '।', 'अनुसार', 'वार्ड', 'ऋषांक', '।', 'स', 'भाजप', 'कौ', 'राजोरिय', ',', 'बार्ड', '20', 'स', 'भाजप', 'क', 'संदीप', 'मौजूद', 'थ', '।', 'एसडीपम', 'एवं', 'हिट्निंग', 'सिंह', ',', 'एसडीओप', 'पुलिस', 'बीऐद्र', 'बहादुर\nप', 'चिपय', 'क', 'चयन', 'कर', 'सक', 'इस', 'सबंध', '.', '.', '.', 'कलेक्टरः', 'एव', 'किल', ',', 'लिवांचन', 'शिलय', 'तनु', 'गौए', 'क', 'विेत', 'घोकित', 'सिर', 'गुल', 'चार', ']', 'स', 'आज', 'क', 'आकिलर', 'अमिनेक', 'सिंए', 'ड', 'और', '.', 'कि', 'टाई', 'एच', 'ज', 'प', 'लहलीकबर\nम', 'निर्देश', 'जात', 'कर', 'द', 'गए', 'हैं', '।', 'परध्यमिक', '।', 'अधिकार', 'नीरज', 'कुमार', 'सिंह', 'न', 'किय', 'गय', 'है', '।', 'महिम', 'हि', 'जौर', ',', 'छार्ड', '22', 'स', 'निर्दलीय', 'प्रेक्षक', 'अनंतनारायण', 'अरोर', 'न', 'सबस', 'पहल', 'विकास', 'जैन', 'सहित', 'अन्य', 'अधिकार', 'मँजूद\nकथ', 'मल', 'दव', 'पाय', 'प्र', 'संस्थाओं', 'म', '.', 'मतगणन', 'कैद', 'लय', 'सा ...
#
#  Lemmatized:
#  ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '' ...
#
#  POS Tags:
#  [('ज्ाईंदुनिया', 'JJ'), ('*', 'NNP'), ('दमोह', 'NNP'), ('*', 'NNP'), ('छतरपुरण्टीकमगढ़', 'NNP'), ('*', 'NNP'), ('्पन्ना', 'NNP'), ('"', 'NNP'), ('खंडवा', 'NNP'), ('*', 'NNP'), ('हरदा', 'NNP'), ('न्होशंगाबाद', 'NNP'), ('*', 'NNP'), ('्बैतूल', 'NNP'), ('/', 'NNP'), ('सारणी', 'NNP'), ('/', 'NNP'), ('मुलताई', 'NNP'), ('.', '.'), ('.', '.'), ('.', '.'), ('धाग्र', 'NN'), (',', ','), ('गा', 'NNP'), ('बुत्ई2०', 'NNP'), ('हैः\nकांग्रेस\nशव', 'NNP'), ('भाजपा', 'NNP'), ('23', 'CD'), (',', ','), ('कांग्रेस', 'VBD'), ('5', 'CD'), ('और', 'JJ'), ('5', 'CD'), ('वार्डो\nसकेंगे', 'JJ'), ('तीन', 'NNP'), ('भाषा', 'NNP'), ('विषय', 'NNP'), ('का', 'NNP'), ('चयन', 'VBD'), ('५', 'CD'), ('१', 'CD'), ('का', 'NN'), ('ही\nमंडल', 'NNP'), ('हि', 'NNP'), ('पद', 'NNP'), ('जुक', 'NNP'), (';', ':'), ('हें', 'NNP'), ('पक', 'NNP'), ('मयंक', 'NNP'), ('॥', 'NNP'), ('ज्ल्कम', 'NNP'), ('हि', 'NNP'), ('तरीके\n520', 'NNP'), ('नागा', 'NNP'), ('इवाए', 'VBD'), ('७', 'CD'), ('फेबुसममका', 'NNP'), ('ह्', 'NNP'), ('मल', 'NNP'), ('£', 'NNP'), ('&', 'CC'), ('हिट', 'NNP'), ('वर्ण', 'NNP'), ('तरीके', 'NNP'), ('से', 'NNP'), ('चुनाव', 'NNP'), ('की', 'NNP'), ('कार्यवाही', 'NNP'), ('पूर्ण\nके', 'NNP'), ('लिए', 'NNP'), ('विद्या', 'NNP'), ('को', 'NNP'), ('निर्धारित', 'NNP'), ('भाषा', 'NNP'), ('विषयों', 'NNP'), ('मे', 'VBD'), ('६५5', 'CD'), ('।', 'NN'), (';', ':'), ('2', 'CD'), ('न', 'NN'), ('/', 'NNP'), ('आ८2', 'NNP'), ('दर', 'VBD'), ('7', 'CD'), ('४', 'CD'), ('॥', 'NN'), ('नगतीय', 'NNP'), ('निकाय', 'NNP'), ('निर्वाचत', 'NNP'), ('2022', 'CD'), ('कराया', 'NNP'), (',', ','), ('तदोपरांत', 'NNP'), ('स्ट्रांग', 'NNP'), ('रूम', 'NNP'), ('से', 'NNP'), ('ईच्हीएम\nसे', 'NNP'), ('कोई', 'NNP'), ('तीन', 'NNP'), ('विषय', 'NNP'), ('का', 'NNP'), ('चयन', 'NNP'), ('करना', 'NNP'), ('होगा', 'NNP'), ('।', 'NNP'), ('.', '.'), ('।', 'CC'), ('20.0', 'CD'), ('मन', 'JJ'), ('।', 'NNP'), ('हे', 'NNP'), ('श', 'VBD'), ('5', 'CD'), ('आज', 'NN'), (',', ','), ('पा', 'NNP'), (',', ','), ('पर', 'NNP'), ('के', 'NNP'), ('तहत', 'NNP'), ('दूसरे', 'NNP'), ('चरण', 'NNP'), ('की', 'NNP'), ('मतगणना', 'NNP'), ('आज', 'NNP'), ('गणना', 'NNP'), ('कक्ष', 'NNP'), ('यें', 'NNP'), ('पहुचने', 'NNP'), ('उपरांत', 'NNP'), ('घतगणना\nेशकल', 'NNP'), ('स्किल', 'NNP'), ('क्लीक्केशत', 'NNP'), ('फंसंवक', 'NNP'), ('वषय', 'NNP'), ('ही', 'VBD'), ('०', 'CD'), ('हैं', 'JJ'), ('।', 'NN'), ('.', '.'), ('ढ', 'CC'), ('है', 'JJ'), ('भ', 'NNP'), ('-', ':'), ('जज', 'NN'), ('डा', 'JJ'), ('ते', 'NNP'), ('ये', 'NNP'), ('वि', 'NNP'), ('बम', 'NNP'), ('हु', 'NNP'), ('व', 'NNP'), ('आप\nका', 'NNP'), ('चयन', 'NNP'), ('करे', 'NNP'), ('वाले', 'NNP'), ('विद्यार्थियों', 'NNP'), ('को', 'NNP'), ('निर्धारित', 'NNP'), ('$', '$'), ('हि', 'NNP'), ('डे', 'NNP'), (';', ':'), ('*', 'NNP'), ('ज्ै', 'NNP'), ('स्थलों', 'NNP'), ('पर', 'NNP'), ('संपन्न', 'NNP'), ('हुई', 'NNP'), ('।', 'NNP'), ('अपने', 'NNP'), ('निर्धारित', 'NNP'), ('कलेक्टर', 'NNP'), ('नाथूग़म', 'NNP'), ('गौड़', 'NNP'), ('ने', 'NNP'), ('भी', 'NNP'), ('एडीशनल\nका', 'NNP'), ('चन', 'NNP'), ('करे', 'NNP'), ('वाले', 'NNP'), ('विवि', 'NNP'), ('को', 'NNP'), ('निया', 'NNP'), ('।', 'NNP'), ('।', 'VBD'), ('2', 'CD'), ('कं', 'NNP'), ('उसपर', 'NNP'), ('एउलीएस', 'NNP'), ('एवं', 'NNP'), ('रिटनिंग', 'NNP'), ('आफिसर', 'NNP'), ('.', '.'), ('एसपी', 'VB'), ('शिव', 'JJ'), ('कुमार', 'NNP'), ('सिंह', 'NNP'), ('के', 'NNP'), ('साथ', 'NNP'), ('मतगणना\nचबन', 'NNP'), ('करना', 'NNP'), ('होगा', 'NNP'), ('।', 'NNP'), ('चिल्ड़र', 'NNP'), ('विध', 'NNP'), ('स्पेशल', 'NNP'), ('नीड', 'NNP'), ('.', '.'), ('.', '.'), ('।', 'JJ'), ('>', 'JJ'), ('हू', 'NN'), ('हा', 'NNP'), ('का', 'NNP'), ('अभिषेक', 'NNP'), ('गः', 'NNP'), ('आकर', 'NNP'), ('एवं', 'NNP'), ('प्रेक्षक', 'NNP'), ('स्थल', 'NNP'), ('पहुंचकर', 'NNP'), ('जायजा', 'NNP'), ('लिया', 'NNP'), ('और\nके', 'NNP'), ('विद्यार्थी', 'NNP'), ('गणित', 'NNP'), ('अथवा', 'NNP'), ('विज्ञान', 'NNP'), ('के', 'NNP'), ('स्थान', 'NNP'), ('पर', 'NNP'), ('>', 'NNP'), ('है', 'NNP'), ('-', ':'), ('>', 'NN'), ('अनंतनारायण', 'JJ'), ('अरोरा', 'NNP'), ('तथा', 'NNP'), ('जनप्रतिनिधियों', 'NNP'), ('मतगणना', 'NNP'), ('कार्य', 'NNP'), ( ...
#
#  Named Entities:
#
# खंडवा --> LOC
# सारणी --> MISC
# मुलताई --> MISC
# गा --> LOC
# मंडल हि --> MISC
# हि --> LOC
# स्ट्रांग रूम --> MISC
# । --> MISC
# । --> MISC
# । --> MISC
# गणना --> LOC
# फंसंवक --> LOC
# । --> MISC
# वि बम --> MISC
# हु --> LOC
# हि --> LOC
# गौड़ --> MISC
# एडीशनल --> MISC
# एउलीएस एवं रिटनिंग --> MISC
# एसपी --> MISC
# साथ --> MISC
# विध --> MISC
# । --> MISC
# गः --> MISC
# एवं प्रेक्षक --> MISC
# अथवा --> PER
# स्थान --> LOC
# अथवा गायन बादन --> PER
# तहसीलदार --> MISC
# वार्ड 6 --> LOC
# में स्ट्रांग --> MISC
# प्राप्त --> MISC
# वार्ड --> MISC
# खुलवाई --> MISC
# सहायक रिटनिंग ताथुयम गौड़ --> MISC
# एसडीएम एवं --> LOC
# सकेंगे --> MISC
# साथ --> MISC
# परीक्षार्थियों --> MISC
# यादव --> LOC
# चार्ड 8 --> LOC
# भाषा --> LOC
# मे --> MISC
# दो --> MISC
# वर्मा --> MISC
# वार्ड --> MISC
# बहादुर --> MISC
# ूट प्रदान --> MISC
# साथने --> MISC
# वार्ड --> MISC
# राजोरिया --> LOC
# बार्ड 20 --> LOC
# एवं --> MISC
# एसडीओपी --> MISC
# बहादुर --> MISC
# गुल चार --> MISC
# टाई --> MISC
# में --> MISC
# । परध्यमिक । --> MISC
# गया है --> MISC
# हि --> LOC
# छार्ड 22 --> LOC
# में --> MISC
# सांस कॉलेज में --> MISC
# ग्याशी सं्रीष वाध्याय --> PER
# गणना --> LOC
# लिए प्रवेश संबंधी --> MISC
# वार्ड 3 --> LOC
# चंद्रमोहन --> MISC
# वार्ड 4 --> LOC
# वार्ड 24 --> LOC
# वार्ड 5 --> MISC
# चार्ड 25 --> LOC
# थ्र् --> MISC
# एवं --> MISC
# सुचारू --> PER
# वार्ड पुर --> LOC
# चिविर --> MISC
# एवं --> MISC
# संचालन --> PER
# उपाध्याय --> MISC
# राहुल गौर --> LOC
# बार्द --> LOC
# वैंदूलेडा --> MISC
# उतापुर --> MISC
# । --> MISC
# समस्त राजस्व --> MISC
# रावत --> LOC
# थार --> MISC
# रिचा --> LOC
# वार्ड $ --> LOC
# वार्ड 29 --> LOC
# जाग --> LOC
# यान --> MISC
# भूमिका --> MISC
# वार्ड 0 --> LOC
# वार्ड 30 --> LOC
# यादव --> LOC
# ऑफिसर --> LOC
# ग्रीवा --> MISC
# या --> MISC
# गणेश बाबरिया --> PER
# वार्ड 32 --> LOC
# ्ा रु --> MISC
# पावन --> LOC
# । --> MISC
# चार्ड । --> MISC
# मालवीव, --> MISC
# एवं --> MISC
# ग्रमाण --> MISC
# गये है --> MISC
# श्री चार्ड 3 --> MISC
# वर्षा भार --> MISC
# बार्ड --> MISC
# वितरित --> MISC
# मोलिक करव्थ का --> MISC
# बालन --> PER
# । --> MISC
# खा --> PER
# । --> MISC
# मोहिनी --> MISC
# बार्ड 5 --> MISC
# । --> MISC
# शान --> MISC
# स्वागत बीजैपी --> MISC
# में --> LOC
# राष्मान एवं खंडवा --> MISC
# मोष्बाईल --> LOC
# सब सदुओं --> PER
# वि --> LOC
# साथ --> MISC
# गया --> ORG
# यहां --> ORG
# वाह --> MISC
# बड़ी राजनीतिक --> MISC
# गया --> LOC
# बार --> MISC
# यहां --> ORG
# या --> MISC
# रिताता --> MISC
# भागषा --> MISC
# । --> MISC
# रु कं! है है --> MISC
# में उत्तमपालसिह --> MISC
# हो --> MISC
# एवं विधिक --> MISC
# है --> MISC
# बिका --> MISC
# लिये --> LOC
# बातें --> LOC
# पार्षद --> LOC
# बावजूद --> MISC
# चही मिला है --> MISC
# पुष्टि --> PER
# बैवारी --> MISC
# । --> MISC
# स्थान --> LOC
# विभाग --> MISC
# में --> MISC
# बाजी चलती --> MISC
# स्थान --> MISC
# स्थान --> LOC
# चह़ढं --> LOC
# मोहन --> LOC
# खबर --> LOC
# पाताल मेले --> LOC
# गति आभाए खा --> PER
# चुन --> MISC
# मिदेलाव पांव धाम --> MISC
# गाना जाइए है --> MISC
# सकेंगे --> MISC
# रखें --> MISC
# तन-मन-ध्न --> LOC
# गोरख --> MISC
# साथ यहां --> MISC
# खेल --> LOC
# । --> MISC
# में स्वागत --> MISC
# साहू --> MISC
# चेताओ --> MISC
# रा --> MISC
# सुर --> MISC
# में सुर --> MISC
# उस्हें भनपा --> PER
# मा --> MISC
# बड़ खबर --> MISC
# वगडी --> MISC
# लिये राज्य --> ORG
# राजपाल --> MISC
# महेंद्र --> MISC
# बड़ी संख्या में मिली --> MISC
# मिर्दलीय --> LOC
# रणनीति मही --> MISC
# रहती --> MISC
# निखिलेश खंडेलवाल --> MISC
# पार्षद --> LOC
# बागी --> MISC
# फेर --> ORG
# रोपेश --> MISC
# । --> MISC
# होने मे रोडा --> MISC
# पाद --> MISC
# खदान --> LOC
# मिलेगी --> MISC
# सारणी --> MISC
# में सुखाढाना चेलादनों --> MISC
# घोड़ाडोंगरी --> MISC
# सारनी में --> MISC
# रूप --> MISC
# सत्ता --> MISC
# सात --> MISC
# चुका है --> MISC
# स्थिति में --> ORG
# हड़ताल --> LOC
# एवं --> MISC
# हि --> LOC
# तैयारी --> MISC
# स्थिति --> MISC
# रूप --> MISC
# में --> LOC
# माध्यम --> LOC
# में --> LOC
# गया --> LOC
# में --> LOC
# वाहन --> MISC
# स्थापना --> MISC
# जाएगी --> MISC
# बात भारतीय जनता --> MISC
# समाप्त --> MISC
# है --> MISC
# घाहन --> PER
# हि --> LOC
# माध्यम --> LOC
# बात सार्थक --> MISC
# में हाल --> MISC
# स्थित ा --> MISC
# स्थापित --> MISC
# छेरी --> MISC
# खाली --> MISC
# मुख्यमंत्री --> MISC
# विकास --> LOC
# लेने बालों की लगी --> PER
# संभव --> MISC
# में --> LOC
# रही थी इसी उनकी --> MISC
# एवं --> MISC
# माध्यम --> LOC
# पालिका --> MISC
# सारमी --> MISC
# हड़ताल --> LOC
# थो --> MISC
# इज --> MISC
# उन्होंने --> MISC
# दिखने --> ORG
# । --> MISC
# है --> MISC
# मास --> MISC
# सारनी में पावर --> MISC
# पैनल --> PER
# में --> LOC
# स्थापित --> MISC
# एनटीपीसी --> MISC
# वो --> MISC
# माध्यन --> LOC
# रुपचंद पिता मरसिह --> MISC
# रोजार --> MISC
# उन्होंने --> MISC
# गया --> LOC
# सारनी में --> MISC
# मिले --> LOC
# पिककअप --> MISC
# बेलप --> MISC
# चुजुर्ग --> MISC
# होने पर गति और मोहर --> MISC
# पाचर --> MISC
# वाइन --> MISC
# बड़वाह --> LOC
# खदान --> LOC
# माध्यम --> MISC
# सारनी में --> MISC
# रूप --> MISC
# लाया --> PER
# होने --> LOC
# बाद --> MISC
# स्थिति में --> MISC
# तैयार की गई थी --> MISC
# यान में --> MISC
# बार --> MISC
# में --> LOC
# एवं --> MISC
# फावर --> MISC
# सुरेन्र --> LOC
# खेत --> PER
# खदान --> LOC
# सौगात --> PER
# मिलेगी --> MISC
# चर्चा --> MISC
# में --> ORG
# स्थित --> LOC
# एवं --> MISC
# उन्होंने --> MISC
# हाथ --> MISC
# में --> LOC
# राजनीति --> LOC
# माध्यम --> LOC
# एमपी --> MISC
# बाहन --> MISC
# में व्यक्धात --> MISC
# हड़ताल --> LOC
# विरोध किया गया --> LOC
# खड़ा --> ORG
# चुजुर्प --> MISC
# । --> MISC
# बितरण --> MISC
# छतरपुर संदीप --> LOC
# छत्तपुर --> LOC
# रुपये --> MISC
# ५ः ९ --> MISC
# पानी --> MISC
# । --> MISC
# यें निवासरत गरीबों --> MISC
# में --> LOC
# लिये --> LOC
# । --> MISC
# मैदानी ग्रहण --> MISC
# माध्यम --> LOC
# राजस्व --> MISC
# एवं --> MISC
# में ग्टीय --> MISC
# पालिका --> MISC
# मैं --> ORG
# हूं --> MISC
# में --> LOC
# एबं --> MISC
# परिषदों --> MISC
# में --> MISC
# है --> MISC
# खुद --> MISC
# । --> MISC
# बात का बिरोध --> MISC
# साफ --> MISC
# में --> MISC
# स्वास्थ्य --> ORG
# महिला एवं बाल --> MISC
# खिरिया --> LOC
# अच्छी --> LOC
# ध्यान --> MISC
# मनपानो --> MISC
# में --> LOC
# बल्वों --> MISC
# । --> MISC
# विभाग --> MISC
# में दिख रहा है। --> MISC
# साथ --> MISC
# खिलवाड़ --> MISC
# में --> MISC
# लिए खिरिया में --> ORG
# दो --> MISC
# सक्रिय सहभागिता --> MISC
# मामला --> LOC
# गरीब वर्ग के --> ORG
# संदीष सोनी बात --> LOC
# है --> MISC
# । --> MISC
# जिससे उल्टा --> MISC
# उन्होंने --> MISC
# खिरिया --> LOC
# यू --> MISC
# अच्छी --> LOC
# इनका --> MISC
# बात --> MISC
# ढिल््ला --> MISC
# उद्यमियों --> MISC
# संदीप सोनी विधालय कि गरकार हाया --> MISC
# रा है --> MISC
# ससम्मान --> MISC
# पथारेया
# फहराबे --> MISC
# गनमजी --> MISC
# में --> MISC
# साथ --> MISC
# एवं --> MISC
# खुद --> MISC
# । --> MISC
# जाएगी --> MISC
# बनाकर --> MISC
# वरिधालय --> MISC
# हुए जब गांव --> MISC
# में --> MISC
# प्रधानमंत्री --> MISC
# मुख्यमंत्री --> MISC
# सिशा --> LOC
# फहराये बल्कि समाज --> ORG
# लिये --> LOC
# लगाकर साफ --> MISC
# है --> MISC
# । --> MISC
# बात --> MISC
# गयी --> MISC
# उन्होंने --> MISC
# खुलने --> MISC
# में --> LOC
#
#  Detected Language: hi
#
#  Summary:
#  ज्ाईंदुनिया *दमोह *छतरपुरण्टीकमगढ़*्पन्ना "खंडवा *हरदा न्होशंगाबाद*्बैतूल/सारणी/मुलताई... धाग्र, गा बुत्ई2० हैः
# कांग्रेस
# शव भाजपा 23, कांग्रेस 5 और 5 वार्डो
